# %% [markdown]
# # Train the network on developpment set
#
#
# NB : faire un test sur le set d'evaluation avec quelques fichiers test avec des calculs de Precision, Recall, quelques spectros, les labels
#
# ## Import functions

# %% [markdown]
# #### <span style="color:red">*JUST RUN CELL*</span>

# %%
import os 
import sys
import numpy as np
#os.chdir(os.path.join("/home/datawork-osmose/",'osmoseNotebooks_v0','source'))

with open('path_codes.txt') as f:
    codes_path = f.readlines()[0]
os.chdir(os.path.join(codes_path))

from train_network import TrainNetwork_main, plot_examples_from_test
from launcher_datasetScale import list_datasets
from check_files_in_ai_folders import check_available_ai_tasks_bm, check_available_ai_datasplit, check_available_formats, check_available_ai_model

# %% [markdown]
# ## Selection of task, benchmark and datasplit

# %%
check_available_ai_tasks_bm()
# Out:
# /
# TaskTEST1/
#     BMTEST1_1/
#              Dataset used :  ['MPSU_ForestouHuella' 'MPSU_ForestouHuella_copy']
# Task_Glider_PBW_AnnotatorAnalysis/
#     BM_merged15/
#              Dataset used :  ['Glider']
#     BM_EXP/
#              Dataset used :  ['Glider']
#     Comp_BM_curves/
#     BM_merged6/
#              Dataset used :  ['Glider']
#     BM_merged2_2/
#              Dataset used :  ['Glider']
#     BM_merged2_3/
#              Dataset used :  ['Glider']
#     BM_merged2_4/
#              Dataset used :  ['Glider']
#     BM_merged2_5/
#              Dataset used :  ['Glider']
#     BM_merged2_6/
#              Dataset used :  ['Glider']
#     BM_merged2_7/
#              Dataset used :  ['Glider']
#     BM_merged2_8/
#              Dataset used :  ['Glider']
#     BM_merged8/
#              Dataset used :  ['Glider']
#     BM_merged10/
#              Dataset used :  ['Glider']
#     BM_merged12/
#              Dataset used :  ['Glider']
#     BM_merged14/
#              Dataset used :  ['Glider']
#     BM_merged2_9/
#              Dataset used :  ['Glider']
#     BM_merged2_10/
#              Dataset used :  ['Glider']
#     WeakLabelling_AllAnnotation/
#              Dataset used :  ['Glider']
#     BM_AN_Nassau/
#              Dataset used :  ['Glider']
#     BM_AN_Shanghai/
#              Dataset used :  ['Glider']
#     BM_AN_Civitavecchia/
#              Dataset used :  ['Glider']
#     BM_AN_Galveston/
#              Dataset used :  ['Glider']
#     BM_AN_Venice/
#              Dataset used :  ['Glider']
#     BM_AN_Fukuoka/
#              Dataset used :  ['Glider']
#     BM_AN_Naples/
#              Dataset used :  ['Glider']
#     BM_AN_Bridgetown/
#              Dataset used :  ['Glider']
#     BM_AN_Valletta/
#              Dataset used :  ['Glider']
#     BM_AN_Rostock/
#              Dataset used :  ['Glider']
#     BM_AN_Dubrovnik/
#              Dataset used :  ['Glider']
#     BM_AN_Mahahual/
#              Dataset used :  ['Glider']
#     BM_AN_Ensenada/
#              Dataset used :  ['Glider']
#     BM_AN_Tunis/
#              Dataset used :  ['Glider']
#     BM_AN_Funchal/
#              Dataset used :  ['Glider']
#     BM_AN_Tallinn/
#              Dataset used :  ['Glider']
#     BM_AN_Malaga/
#              Dataset used :  ['Glider']
#     BM_AN_Helsinki/
#              Dataset used :  ['Glider']
#     BM_AN_Valencia/
#              Dataset used :  ['Glider']
#     BM_FULL_EVAL/
#              Dataset used :  ['Glider']
#     BM_FULL_EVAL_long/
#              Dataset used :  ['Glider']
# Task_Test_Apocado_whistles/
#     BM_1/
#              Dataset used :  ['APOCADO_IROISE_C2D1_07072022']
# Task_Det_PBW/
#     TEST1/
#              Dataset used :  ['Dataset2015_AUS']
#     TRAIN_Glider/
#              Dataset used :  ['Glider']
#     TRAIN_Glider_long/
#              Dataset used :  ['Glider']
#     Train_multilabels_grouped15/
#              Dataset used :  ['Glider']

# %%
Task_ID = 'Task_Det_PBW'
BM_Name = 'TRAIN_multilabels_grouped15'

# %%
check_available_ai_datasplit(Task_ID, BM_Name)
# Out:
# Datasplits available in this task and this benchmark :
# info_datasplit/
#     split_for_eval_1/

# %%
SplitName = 'split_for_eval_1'

# %% [markdown]
# ## Check model
#
# Choose the name of your new model. If the name already exist, it will be overwrited.

# %%
check_available_ai_model(Task_ID, BM_Name)
# Out:
# Models available in this task and this benchmark :
#     m1/

# %%
Version_name = 'm1'

# %% [markdown]
# ## Check all spectrograms already available

# %%
check_available_formats(Task_ID, BM_Name)
# Out:
# _______________
# Dataset :  Glider
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_500
#          499_198_50
#      50_250
#          512_512_92

# %% [markdown]
# Enter the spectrogram format in the corresponding parameters.
# As list, to match with the list of dataset used in the benchmark (checked above).
#
# Example with 2 dataset :
# - ``nfft`` = [1024, 4096]
# - ``window_size`` = [1024, 1024]
# - ``overlap`` = [80, 50]
#
#
# It is also possible to use only .wav file as input, new spectrograms will be computed iteratively.
# In this case, please fill also some other parameters for the computation of the new spectrograms :
#
# Nb : The wavefiles are normalized one by one using "data = (data - np.mean(data)) / np.std(data)". The normalization from instruments values to get absolute pressure level will be add on the next version.
#
#
# - ``dynamic_min`` = [-40, -40]
# - ``dynamic_max`` = [40, 40]
# - ``scaling`` = ['spectrum', 'spectrum']

# %%
input_data_format = 'audio' # 'audio'
# 'spectrogram' : use already computed spectrogram
# 'audio' : use .wav file, spectrogram will be computed iteratively

nfft = [512]
window_size = [512]
overlap = [92]


#Useless if input_data_format = 'spectrogram'
dynamic_min = [-20]
dynamic_max = [20]
scaling = ['spectrum'] # 'spectrum', 'density'

# %% [markdown]
# ### Set model parameters
#
# #### <span style="color:green">*LIST OF PARAMETERS*</span>
#
# - `` ModelName `` : Architecture of the model. Please, select one in this list : (for more details, check : https://pytorch.org/vision/main/models.html)
#     - 'CNN3_FC1'
#     - 'CNN3_FC3'
#     - 'resnet18'
#     - 'resnet50'
#     - 'resnet101'
#     - 'vgg11'
#     - 'vgg11_bn'
#     - 'vgg13'
#     - 'vgg13_bn'
#     - 'vgg19'
#     - 'vgg19_bn'
#     - 'alexnet'
#
#
# - `` use_pretrained `` : (for more details, check : https://pytorch.org/vision/main/models.html) (By default : use_pretrained = True)
#     - True : if you want to used already pretrained network one reference image dataset and just finetun the last layer
#     - False : if you want to train your network from random weights and adjust all layers
#
#
#
# - `` TrainsetRatio `` : ratio between 0 and 1 of all the developpement set that will be used for the training (the oser part is for testing). (if None : TrainSetRatio = 0.9)
#
# - `` batch_size `` : Number of spectrograms per batch (if None : batch_size = 10)
# - `` learning_rate `` : step size at each iteration while moving toward a minimum of a loss function (if None : learning_rate = 1e-3)
# - `` num_epochs `` : Number of iteration over all developpement set (if None : num_epochs = 10)

# %%
ModelName = 'CNN4_FC3'
use_pretrained = True

TrainsetRatio = 0.8
batch_size = 10
learning_rate = 3e-4
num_epochs = 100
shuffle = 'True'

# %%
parameters = {'TrainsetRatio':TrainsetRatio, 'batch_size':batch_size, 'learning_rate':learning_rate, 'num_epochs':num_epochs, 'shuffle':shuffle, 'use_pretrained':use_pretrained, 'input_data_format':input_data_format, 'nfft':nfft, 'window_size':window_size, 'overlap':overlap, 'dynamic_min':dynamic_min, 'dynamic_max':dynamic_max, 'scaling':scaling}

# %%
model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
# Out:
# MODEL INFORMATION :
#
# CNN4_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 conv4.0.weight
# 	 conv4.0.bias
# 	 conv4.1.weight
# 	 conv4.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/100]  -- Loss = 0.7048857305198908  --  iteration [96/96]
# Epoch TEST [1/100]  -- Loss = 0.7120614970723788  --  iteration [24/24]
# Epoch TRAIN [2/100]  -- Loss = 0.7013725272069374  --  iteration [96/96]
# Epoch TEST [2/100]  -- Loss = 0.7065282861391703  --  iteration [24/24]
# Epoch TRAIN [3/100]  -- Loss = 0.6989501044154167  --  iteration [96/96]
# Epoch TEST [3/100]  -- Loss = 0.7025980105002722  --  iteration [24/24]
# Epoch TRAIN [4/100]  -- Loss = 0.696223105614384  --  iteration [96/96]]
# Epoch TEST [4/100]  -- Loss = 0.6988399028778076  --  iteration [24/24]
# Epoch TRAIN [5/100]  -- Loss = 0.6942006926983595  --  iteration [96/96]
# Epoch TEST [5/100]  -- Loss = 0.6944005141655604  --  iteration [24/24]
# Epoch TRAIN [6/100]  -- Loss = 0.6923910193145275  --  iteration [96/96]
# Epoch TEST [6/100]  -- Loss = 0.6916886990269026  --  iteration [24/24]
# Epoch TRAIN [7/100]  -- Loss = 0.6906724677731594  --  iteration [96/96]
# Epoch TEST [7/100]  -- Loss = 0.6882959554592768  --  iteration [24/24]
# Epoch TRAIN [8/100]  -- Loss = 0.6896344640602668  --  iteration [96/96]
# Epoch TEST [8/100]  -- Loss = 0.6864073475201925  --  iteration [24/24]
# Epoch TRAIN [9/100]  -- Loss = 0.6885150937984387  --  iteration [96/96]
# Epoch TEST [9/100]  -- Loss = 0.68380389859279  --  iteration [24/24]4]
# Epoch TRAIN [10/100]  -- Loss = 0.6870658099651337  --  iteration [96/96]
# Epoch TEST [10/100]  -- Loss = 0.680470327536265  --  iteration [24/24]]
# Epoch TRAIN [11/100]  -- Loss = 0.6846032955994209  --  iteration [96/96]
# Epoch TEST [11/100]  -- Loss = 0.678071583310763  --  iteration [24/24]]
# Epoch TRAIN [12/100]  -- Loss = 0.6834596190601587  --  iteration [96/96]
# Epoch TEST [12/100]  -- Loss = 0.6761285538474718  --  iteration [24/24]
# Epoch TRAIN [13/100]  -- Loss = 0.6832348282138506  --  iteration [96/96]
# Epoch TEST [13/100]  -- Loss = 0.6735400184988976  --  iteration [24/24]
# Epoch TRAIN [14/100]  -- Loss = 0.6804845953981081  --  iteration [96/96]
# Epoch TEST [14/100]  -- Loss = 0.6726355825861295  --  iteration [24/24]
# Epoch TRAIN [15/100]  -- Loss = 0.6788196967293819  --  iteration [96/96]
# Epoch TEST [15/100]  -- Loss = 0.6695403878887495  --  iteration [24/24]
# Epoch TRAIN [16/100]  -- Loss = 0.6757169061650833  --  iteration [96/96]
# Epoch TEST [16/100]  -- Loss = 0.6636051684617996  --  iteration [24/24]
# Epoch TRAIN [17/100]  -- Loss = 0.6793365851044655  --  iteration [96/96]
# Epoch TEST [17/100]  -- Loss = 0.6642607823014259  --  iteration [24/24]
# Epoch TRAIN [18/100]  -- Loss = 0.6776812920967737  --  iteration [96/96]
# Epoch TEST [18/100]  -- Loss = 0.6595970963438352  --  iteration [24/24]
# Epoch TRAIN [19/100]  -- Loss = 0.6748074305554231  --  iteration [96/96]
# Epoch TEST [19/100]  -- Loss = 0.6586041202147802  --  iteration [24/24]
# Epoch TRAIN [20/100]  -- Loss = 0.6723492754002413  --  iteration [96/96]
# Epoch TEST [20/100]  -- Loss = 0.6566714371244112  --  iteration [24/24]
# Epoch TRAIN [21/100]  -- Loss = 0.671911991511782  --  iteration [96/96]]
# Epoch TEST [21/100]  -- Loss = 0.6511714632312456  --  iteration [24/24]
# Epoch TRAIN [22/100]  -- Loss = 0.6692294906824827  --  iteration [96/96]
# Epoch TEST [22/100]  -- Loss = 0.6476684138178825  --  iteration [24/24]
# Epoch TRAIN [23/100]  -- Loss = 0.6677429309735695  --  iteration [96/96]
# Epoch TEST [23/100]  -- Loss = 0.6431406065821648  --  iteration [24/24]
# Epoch TRAIN [24/100]  -- Loss = 0.6683568408091863  --  iteration [96/96]
# Epoch TEST [24/100]  -- Loss = 0.6427828843394915  --  iteration [24/24]
# Epoch TRAIN [25/100]  -- Loss = 0.6624970765163501  --  iteration [96/96]
# Epoch TEST [25/100]  -- Loss = 0.6381062641739845  --  iteration [24/24]
# Epoch TRAIN [26/100]  -- Loss = 0.6639792416244745  --  iteration [96/96]
# Epoch TEST [26/100]  -- Loss = 0.6344314068555832  --  iteration [24/24]
# Epoch TRAIN [27/100]  -- Loss = 0.6506772475938002  --  iteration [96/96]
# Epoch TEST [27/100]  -- Loss = 0.6294914235671362  --  iteration [24/24]
# Epoch TRAIN [28/100]  -- Loss = 0.6531544271856546  --  iteration [96/96]
# Epoch TEST [28/100]  -- Loss = 0.6234413931767145  --  iteration [24/24]
# Epoch TRAIN [29/100]  -- Loss = 0.6446643701444069  --  iteration [96/96]
# Epoch TEST [29/100]  -- Loss = 0.6165332819024721  --  iteration [24/24]
# Epoch TRAIN [30/100]  -- Loss = 0.6387836585442225  --  iteration [96/96]
# Epoch TEST [30/100]  -- Loss = 0.6131573542952538  --  iteration [24/24]
# Epoch TRAIN [31/100]  -- Loss = 0.639501898859938  --  iteration [96/96]]
# Epoch TEST [31/100]  -- Loss = 0.6047547335426012  --  iteration [24/24]
# Epoch TRAIN [32/100]  -- Loss = 0.6256400191535553  --  iteration [96/96]
# Epoch TEST [32/100]  -- Loss = 0.5957807364563147  --  iteration [24/24]
# Epoch TRAIN [33/100]  -- Loss = 0.6186982054884235  --  iteration [96/96]
# Epoch TEST [33/100]  -- Loss = 0.5885160764058431  --  iteration [24/24]
# Epoch TRAIN [34/100]  -- Loss = 0.6028281360243758  --  iteration [96/96]
# Epoch TEST [34/100]  -- Loss = 0.5786332376301289  --  iteration [24/24]
# Epoch TRAIN [35/100]  -- Loss = 0.5939073478803039  --  iteration [96/96]
# Epoch TEST [35/100]  -- Loss = 0.58975691969196  --  iteration [24/24]4]
# Epoch TRAIN [36/100]  -- Loss = 0.5797460833564401  --  iteration [96/96]
# Epoch TEST [36/100]  -- Loss = 0.5549683918555578  --  iteration [24/24]
# Epoch TRAIN [37/100]  -- Loss = 0.5702357431873679  --  iteration [96/96]
# Epoch TEST [37/100]  -- Loss = 0.5246587072809538  --  iteration [24/24]
# Epoch TRAIN [38/100]  -- Loss = 0.5493503843123714  --  iteration [96/96]
# Epoch TEST [38/100]  -- Loss = 0.54299546033144  --  iteration [24/24]4]
# Epoch TRAIN [39/100]  -- Loss = 0.5215901096041003  --  iteration [96/96]
# Epoch TEST [39/100]  -- Loss = 0.5347131292025248  --  iteration [24/24]
# Epoch TRAIN [40/100]  -- Loss = 0.5074177806576093  --  iteration [96/96]]
# Epoch TEST [40/100]  -- Loss = 0.49800290788213414  --  iteration [24/24]
# Epoch TRAIN [41/100]  -- Loss = 0.48271572186301154  --  iteration [96/96]
# Epoch TEST [41/100]  -- Loss = 0.4734064005315304  --  iteration [24/24]]
# Epoch TRAIN [42/100]  -- Loss = 0.47558203246444464  --  iteration [96/96]
# Epoch TEST [42/100]  -- Loss = 0.4770346079021692  --  iteration [24/24]]
# Epoch TRAIN [43/100]  -- Loss = 0.45570650044828653  --  iteration [96/96]
# Epoch TEST [43/100]  -- Loss = 0.46707634689907235  --  iteration [24/24]
# Epoch TRAIN [44/100]  -- Loss = 0.44064535076419514  --  iteration [96/96]
# Epoch TEST [44/100]  -- Loss = 0.49627338846524555  --  iteration [24/24]
# Epoch TRAIN [45/100]  -- Loss = 0.4456072631292045  --  iteration [96/96]]
# Epoch TEST [45/100]  -- Loss = 0.47292597219347954  --  iteration [24/24]
# Epoch TRAIN [46/100]  -- Loss = 0.445109773427248  --  iteration [96/96]]]
# Epoch TEST [46/100]  -- Loss = 0.49203212186694145  --  iteration [24/24]
# Epoch TRAIN [47/100]  -- Loss = 0.4096660002445181  --  iteration [96/96]
# Epoch TEST [47/100]  -- Loss = 0.49850185153385  --  iteration [24/24]4]]
# Epoch TRAIN [48/100]  -- Loss = 0.4264598726294935  --  iteration [96/96]]
# Epoch TEST [48/100]  -- Loss = 0.47610831415901583  --  iteration [24/24]
# Epoch TRAIN [49/100]  -- Loss = 0.39602408387387794  --  iteration [96/96]
# Epoch TEST [49/100]  -- Loss = 0.4757030612478654  --  iteration [24/24]]
# Epoch TRAIN [50/100]  -- Loss = 0.40309126232750714  --  iteration [96/96]
# Epoch TEST [50/100]  -- Loss = 0.4401894509792328  --  iteration [24/24]]
# Epoch TRAIN [51/100]  -- Loss = 0.4375630187181135  --  iteration [96/96]]
# Epoch TEST [51/100]  -- Loss = 0.5614344620456299  --  iteration [24/24]
# Epoch TRAIN [52/100]  -- Loss = 0.41275190546487767  --  iteration [96/96]
# Epoch TEST [52/100]  -- Loss = 0.5019549249360958  --  iteration [24/24]
# Epoch TRAIN [53/100]  -- Loss = 0.3876570579595864  --  iteration [96/96]]
# Epoch TEST [53/100]  -- Loss = 0.4666605281333129  --  iteration [24/24]]
# Epoch TRAIN [54/100]  -- Loss = 0.39662707208966214  --  iteration [96/96]
# Epoch TEST [54/100]  -- Loss = 0.4687116853892803  --  iteration [24/24]]
# Epoch TRAIN [55/100]  -- Loss = 0.3986411594475309  --  iteration [96/96]]
# Epoch TEST [55/100]  -- Loss = 0.4571463360140721  --  iteration [24/24]]
# Epoch TRAIN [56/100]  -- Loss = 0.34553451448058087  --  iteration [96/96]
# Epoch TEST [56/100]  -- Loss = 0.5951840387036403  --  iteration [24/24]
# Epoch TRAIN [57/100]  -- Loss = 0.38153935270383954  --  iteration [96/96]
# Epoch TEST [57/100]  -- Loss = 0.4605800857146581  --  iteration [24/24]]
# Epoch TRAIN [58/100]  -- Loss = 0.3471206027703981  --  iteration [96/96]]
# Epoch TEST [58/100]  -- Loss = 0.5600295681506395  --  iteration [24/24]
# Epoch TRAIN [59/100]  -- Loss = 0.3567488379776478  --  iteration [96/96]]
# Epoch TEST [59/100]  -- Loss = 0.47143492723504704  --  iteration [24/24]
# Epoch TRAIN [60/100]  -- Loss = 0.3368078930458675  --  iteration [96/96]]
# Epoch TEST [60/100]  -- Loss = 0.4189641874593993  --  iteration [24/24]]
# Epoch TRAIN [61/100]  -- Loss = 0.3294338183477521  --  iteration [96/96]]
# Epoch TEST [61/100]  -- Loss = 0.45821083212892216  --  iteration [24/24]
# Epoch TRAIN [62/100]  -- Loss = 0.3182527943669508  --  iteration [96/96]]
# Epoch TEST [62/100]  -- Loss = 0.531073180337747  --  iteration [24/24]]]
# Epoch TRAIN [63/100]  -- Loss = 0.2990298028259228  --  iteration [96/96]]
# Epoch TEST [63/100]  -- Loss = 0.4329684240122636  --  iteration [24/24]]
# Epoch TRAIN [64/100]  -- Loss = 0.29183036542963237  --  iteration [96/96]
# Epoch TEST [64/100]  -- Loss = 0.5161349245657524  --  iteration [24/24]
# Epoch TRAIN [65/100]  -- Loss = 0.2912923489542057  --  iteration [96/96]]
# Epoch TEST [65/100]  -- Loss = 0.4285834749850134  --  iteration [24/24]]
# Epoch TRAIN [66/100]  -- Loss = 0.24148155539296567  --  iteration [96/96]
# Epoch TEST [66/100]  -- Loss = 0.5121694800133506  --  iteration [24/24]]
# Epoch TRAIN [67/100]  -- Loss = 0.235077669727616  --  iteration [96/96]6]
# Epoch TEST [67/100]  -- Loss = 0.5035058554882804  --  iteration [24/24]
# Epoch TRAIN [68/100]  -- Loss = 0.2888928417426844  --  iteration [96/96]]
# Epoch TEST [68/100]  -- Loss = 0.5898438127090534  --  iteration [24/24]
# Epoch TRAIN [69/100]  -- Loss = 0.21609959340033433  --  iteration [96/96]
# Epoch TEST [69/100]  -- Loss = 0.5045239155491194  --  iteration [24/24]]
# Epoch TRAIN [70/100]  -- Loss = 0.25614695146214217  --  iteration [96/96]
# Epoch TEST [70/100]  -- Loss = 0.500930916517973  --  iteration [24/24]4]
# Epoch TRAIN [71/100]  -- Loss = 0.19654353498481214  --  iteration [96/96]
# Epoch TEST [71/100]  -- Loss = 0.5701503741244475  --  iteration [24/24]]
# Epoch TRAIN [72/100]  -- Loss = 0.17976640484994277  --  iteration [96/96]
# Epoch TEST [72/100]  -- Loss = 0.6100317326684793  --  iteration [24/24]
# Epoch TRAIN [73/100]  -- Loss = 0.15739496308378875  --  iteration [96/96]
# Epoch TEST [73/100]  -- Loss = 0.5520987088481585  --  iteration [24/24]
# Epoch TRAIN [74/100]  -- Loss = 0.1895750937789368  --  iteration [96/96]]
# Epoch TEST [74/100]  -- Loss = 0.4770563873462379  --  iteration [24/24]]
# Epoch TRAIN [75/100]  -- Loss = 0.1626274059720648  --  iteration [96/96]]
# Epoch TEST [75/100]  -- Loss = 0.4433259681488077  --  iteration [24/24]]
# Epoch TRAIN [76/100]  -- Loss = 0.13468948751688004  --  iteration [96/96]
# Epoch TEST [76/100]  -- Loss = 0.5335002454618613  --  iteration [24/24]]
# Epoch TRAIN [77/100]  -- Loss = 0.1473097189834031  --  iteration [96/96]]
# Epoch TEST [77/100]  -- Loss = 0.5609282761191329  --  iteration [24/24]
# Epoch TRAIN [78/100]  -- Loss = 0.12134494823597682  --  iteration [96/96]
# Epoch TEST [78/100]  -- Loss = 0.628417049224178  --  iteration [24/24]]
# Epoch TRAIN [79/100]  -- Loss = 0.12315683111470814  --  iteration [96/96]
# Epoch TEST [79/100]  -- Loss = 0.5723589249731352  --  iteration [24/24]
# Epoch TRAIN [80/100]  -- Loss = 0.10900843660541189  --  iteration [96/96]
# Epoch TEST [80/100]  -- Loss = 0.5810016791025797  --  iteration [24/24]
# Epoch TRAIN [81/100]  -- Loss = 0.08816383274582525  --  iteration [96/96]
# Epoch TEST [81/100]  -- Loss = 0.6823743985344967  --  iteration [24/24]
# Epoch TRAIN [82/100]  -- Loss = 0.11171527859793666  --  iteration [96/96]
# Epoch TEST [82/100]  -- Loss = 0.6730857032040755  --  iteration [24/24]
# Epoch TRAIN [83/100]  -- Loss = 0.08339344591270977  --  iteration [96/96]
# Epoch TEST [83/100]  -- Loss = 0.6226262186343471  --  iteration [24/24]
# Epoch TRAIN [84/100]  -- Loss = 0.08340223337775872  --  iteration [96/96]
# Epoch TEST [84/100]  -- Loss = 0.8022949149211248  --  iteration [24/24]
# Epoch TRAIN [85/100]  -- Loss = 0.08645218515691037  --  iteration [96/96]
# Epoch TEST [85/100]  -- Loss = 0.649333439146479  --  iteration [24/24]]
# Epoch TRAIN [86/100]  -- Loss = 0.07431603529888282  --  iteration [96/96]]
# Epoch TEST [86/100]  -- Loss = 0.5712705347687006  --  iteration [24/24]]
# Epoch TRAIN [87/100]  -- Loss = 0.10428165258781519  --  iteration [96/96]
# Epoch TEST [87/100]  -- Loss = 0.8544683152188858  --  iteration [24/24]
# Epoch TRAIN [88/100]  -- Loss = 0.09757172216389638  --  iteration [96/96]
# Epoch TEST [88/100]  -- Loss = 0.8082464047862837  --  iteration [24/24]
# Epoch TRAIN [89/100]  -- Loss = 0.08268868280962731  --  iteration [96/96]
# Epoch TEST [89/100]  -- Loss = 0.7315330542235946  --  iteration [24/24]
# Epoch TRAIN [90/100]  -- Loss = 0.11339430747223862  --  iteration [96/96]]
# Epoch TEST [90/100]  -- Loss = 0.5813533041315774  --  iteration [24/24]
# Epoch TRAIN [91/100]  -- Loss = 0.10141016014191943  --  iteration [96/96]]
# Epoch TEST [91/100]  -- Loss = 0.5807504813807706  --  iteration [24/24]
# Epoch TRAIN [92/100]  -- Loss = 0.10293849630882808  --  iteration [96/96]
# Epoch TEST [92/100]  -- Loss = 0.6112755577390393  --  iteration [24/24]
# Epoch TRAIN [93/100]  -- Loss = 0.059398998848337214  --  iteration [96/96]
# Epoch TEST [93/100]  -- Loss = 0.6932870362264415  --  iteration [24/24]
# Epoch TRAIN [94/100]  -- Loss = 0.06529929130920209  --  iteration [96/96]
# Epoch TEST [94/100]  -- Loss = 0.8728022643675407  --  iteration [24/24]
# Epoch TRAIN [95/100]  -- Loss = 0.08568235297085873  --  iteration [96/96]]
# Epoch TEST [95/100]  -- Loss = 0.7723019514232874  --  iteration [24/24]
# Epoch TRAIN [96/100]  -- Loss = 0.08124586461174961  --  iteration [96/96]
# Epoch TEST [96/100]  -- Loss = 0.7110147684191664  --  iteration [24/24]
# Epoch TRAIN [97/100]  -- Loss = 0.04411608670488931  --  iteration [96/96]]
# Epoch TEST [97/100]  -- Loss = 0.7456461430216829  --  iteration [24/24]
# Epoch TRAIN [98/100]  -- Loss = 0.0750887580992033  --  iteration [96/96]]]
# Epoch TEST [98/100]  -- Loss = 0.7703385523830851  --  iteration [24/24]
# Epoch TRAIN [99/100]  -- Loss = 0.058558128711107806  --  iteration [96/96]
# Epoch TEST [99/100]  -- Loss = 0.7688380597780148  --  iteration [24/24]
# Epoch TRAIN [100/100]  -- Loss = 0.043400553629908245  --  iteration [96/96]
# Epoch TEST [100/100]  -- Loss = 0.8512184545397758  --  iteration [24/24]
# DONE
#
# Train and Test losses over epochs

# %%
from train_network import TrainNetwork_main, plot_examples_from_test

# %%
plot_examples_from_test(model_ft, test_loader, LabelsList)
