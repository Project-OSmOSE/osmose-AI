# %% [markdown]
# # Train the network on developpment set
#
#
# NB : faire un test sur le set d'evaluation avec quelques fichiers test avec des calculs de Precision, Recall, quelques spectros, les labels
#
# ## Import functions

# %% [markdown]
# #### <span style="color:red">*JUST RUN CELL*</span>

# %%
import os 
import sys
import numpy as np
#os.chdir(os.path.join("/home/datawork-osmose/",'osmoseNotebooks_v0','source'))

with open('path_codes.txt') as f:
    codes_path = f.readlines()[0]
os.chdir(os.path.join(codes_path))

from train_network import TrainNetwork_main, plot_examples_from_test
from launcher_datasetScale import list_datasets
from check_files_in_ai_folders import check_available_ai_tasks_bm, check_available_ai_datasplit, check_available_formats, check_available_ai_model

# %% [markdown]
# ## Selection of task, benchmark and datasplit

# %%
check_available_ai_tasks_bm()
# Out:
# /
# TaskTEST1/
#     BMTEST1_1/
#              Dataset used :  ['MPSU_ForestouHuella' 'MPSU_ForestouHuella_copy']
# Task_Glider_PBW_AnnotatorAnalysis/
#     BM_merged15/
#              Dataset used :  ['Glider']
#     BM_merged12/
#              Dataset used :  ['Glider']
#     BM_merged14/
#              Dataset used :  ['Glider']
#     BM_EXP/
#              Dataset used :  ['Glider']
#     BM_FULL_EVAL/
#              Dataset used :  ['Glider']
#     BM_merged1_1/
#              Dataset used :  ['Glider']
#     BM_merged1_2/
#              Dataset used :  ['Glider']
#     BM_merged1_3/
#              Dataset used :  ['Glider']
#     BM_merged1_4/
#              Dataset used :  ['Glider']
#     Comp_BM_curves/
#     BM_merged1_5/
#              Dataset used :  ['Glider']
#     BM_merged1_6/
#              Dataset used :  ['Glider']
#     BM_merged1_7/
#              Dataset used :  ['Glider']
#     BM_merged1_8/
#              Dataset used :  ['Glider']
#     BM_merged1_9/
#              Dataset used :  ['Glider']
#     BM_merged4/
#              Dataset used :  ['Glider']
#     BM_merged6/
#              Dataset used :  ['Glider']
#     BM_merged8/
#              Dataset used :  ['Glider']
#     BM_merged10/
#              Dataset used :  ['Glider']
# Task_Test_Apocado_whistles/
#     BM_1/
#              Dataset used :  ['APOCADO_IROISE_C2D1_07072022']

# %%
Task_ID = 'Task_Glider_PBW_AnnotatorAnalysis'
BM_Name = 'BM_merged1_5'

# %%
check_available_ai_datasplit(Task_ID, BM_Name)
# Out:
# Datasplits available in this task and this benchmark :
# info_datasplit/
#     split_for_eval_1/

# %%
SplitName = 'split_for_eval_1'

# %% [markdown]
# ## Check model
#
# Choose the name of your new model. If the name already exist, it will be overwrited.

# %%
check_available_ai_model(Task_ID, BM_Name)
# Out:
# Models available in this task and this benchmark :

# %%
Version_name = 'm1'

# %% [markdown]
# ## Check all spectrograms already available

# %%
check_available_formats(Task_ID, BM_Name)
# Out:
# _______________
# Dataset :  Glider
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_500
#          499_198_50

# %% [markdown]
# Enter the spectrogram format in the corresponding parameters.
# As list, to match with the list of dataset used in the benchmark (checked above).
#
# Example with 2 dataset :
# - ``nfft`` = [1024, 4096]
# - ``window_size`` = [1024, 1024]
# - ``overlap`` = [80, 50]
#
#
# It is also possible to use only .wav file as input, new spectrograms will be computed iteratively.
# In this case, please fill also some other parameters for the computation of the new spectrograms :
#
# Nb : The wavefiles are normalized one by one using "data = (data - np.mean(data)) / np.std(data)". The normalization from instruments values to get absolute pressure level will be add on the next version.
#
#
# - ``dynamic_min`` = [-40, -40]
# - ``dynamic_max`` = [40, 40]
# - ``scaling`` = ['spectrum', 'spectrum']

# %%
input_data_format = 'spectrogram' # 'audio'
# 'spectrogram' : use already computed spectrogram
# 'audio' : use .wav file, spectrogram will be computed iteratively

nfft = [499]
window_size = [198]
overlap = [50]


#Useless if input_data_format = 'spectrogram'
dynamic_min = [-20]
dynamic_max = [20]
scaling = ['spectrum'] # 'spectrum', 'density'

# %% [markdown]
# ### Set model parameters
#
# #### <span style="color:green">*LIST OF PARAMETERS*</span>
#
# - `` ModelName `` : Architecture of the model. Please, select one in this list : (for more details, check : https://pytorch.org/vision/main/models.html)
#     - 'CNN3_FC1'
#     - 'CNN3_FC3'
#     - 'resnet18'
#     - 'resnet50'
#     - 'resnet101'
#     - 'vgg11'
#     - 'vgg11_bn'
#     - 'vgg13'
#     - 'vgg13_bn'
#     - 'vgg19'
#     - 'vgg19_bn'
#     - 'alexnet'
#
#
# - `` use_pretrained `` : (for more details, check : https://pytorch.org/vision/main/models.html) (By default : use_pretrained = True)
#     - True : if you want to used already pretrained network one reference image dataset and just finetun the last layer
#     - False : if you want to train your network from random weights and adjust all layers
#
#
#
# - `` TrainsetRatio `` : ratio between 0 and 1 of all the developpement set that will be used for the training (the oser part is for testing). (if None : TrainSetRatio = 0.9)
#
# - `` batch_size `` : Number of spectrograms per batch (if None : batch_size = 10)
# - `` learning_rate `` : step size at each iteration while moving toward a minimum of a loss function (if None : learning_rate = 1e-3)
# - `` num_epochs `` : Number of iteration over all developpement set (if None : num_epochs = 10)

# %%
ModelName = 'CNN3_FC3'
use_pretrained = False

TrainsetRatio = 0.8
batch_size = 10
learning_rate = 5e-5
num_epochs = 80
shuffle = 'True'

# %%
parameters = {'TrainsetRatio':TrainsetRatio, 'batch_size':batch_size, 'learning_rate':learning_rate, 'num_epochs':num_epochs, 'shuffle':shuffle, 'use_pretrained':use_pretrained, 'input_data_format':input_data_format, 'nfft':nfft, 'window_size':window_size, 'overlap':overlap, 'dynamic_min':dynamic_min, 'dynamic_max':dynamic_max, 'scaling':scaling}

# %%
model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
# Out:
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/80]  -- Loss = 0.7133760858948032  --  iteration [96/96]
# Epoch TEST [1/80]  -- Loss = 0.6921874384085337  --  iteration [24/24]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
#
# File ~\Documents\PhD\CodesDatarmor\OSmOSEcodesV2\Functions\train_network.py:277, in TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
#     274 print('TRAINNING : ')
#     276 #Launch the training
# --> 277 loss_tab_train, loss_tab_test = train(device, model_ft, optimizer, num_epochs, train_loader, test_loader, weight, model_path, Version_name, ModelName)
#     279 print('DONE')
#     281 #%% Save Model
#     282 #save model
#
# File ~\Documents\PhD\CodesDatarmor\OSmOSEcodesV2\Functions\train_network.py:64, in train(device, model_ft, optimizer, num_epochs, train_loader, test_loader, weight, model_path, Version_name, ModelName)
#      62 epoch_p = epoch + 1
#      63 #Loop For over train set
# ---> 64 for imgs, labels in train_loader:
#      65     #load data and label, send them to device
#      66     imgs = imgs.to(device)
#      67     labels = labels.to(device)
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:1186, in _MultiProcessingDataLoaderIter._next_data(self)
#    1183     return self._process_data(data)
#    1185 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186 idx, data = self._get_data()
#    1187 self._tasks_outstanding -= 1
#    1188 if self._dataset_kind == _DatasetKind.Iterable:
#    1189     # Check for _IterableDatasetStopIteration
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:1142, in _MultiProcessingDataLoaderIter._get_data(self)
#    1140 elif self._pin_memory:
#    1141     while self._pin_memory_thread.is_alive():
# -> 1142         success, data = self._try_get_data()
#    1143         if success:
#    1144             return data
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:990, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#     977 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#     978     # Tries to fetch data from `self._data_queue` once for a given timeout.
#     979     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#     987     # Returns a 2-tuple:
#     988     #   (bool: whether successfully get data, any: data if successful else None)
#     989     try:
# --> 990         data = self._data_queue.get(timeout=timeout)
#     991         return (True, data)
#     992     except Exception as e:
#     993         # At timeout and error, we manually check whether any worker has
#     994         # failed. Note that this is the only mechanism for Windows to detect
#     995         # worker failures.
#
# File ~\anaconda3\lib\queue.py:179, in Queue.get(self, block, timeout)
#     177         if remaining <= 0.0:
#     178             raise Empty
# --> 179         self.not_empty.wait(remaining)
#     180 item = self._get()
#     181 self.not_full.notify()
#
# File ~\anaconda3\lib\threading.py:306, in Condition.wait(self, timeout)
#     304 else:
#     305     if timeout > 0:
# --> 306         gotit = waiter.acquire(True, timeout)
#     307     else:
#     308         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plot_examples_from_test(model_ft, test_loader, LabelsList)

# %%
for i in range(2,11):

    BM_Name = 'BM_merged2_'+str(int(i))
    model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
# Out:
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/80]  -- Loss = 0.7054726959516605  --  iteration [96/96]
# Epoch TEST [1/80]  -- Loss = 0.6841349626580874  --  iteration [24/24]
# Epoch TRAIN [2/80]  -- Loss = 0.6682012391587099  --  iteration [96/96]
# Epoch TEST [2/80]  -- Loss = 0.6821077143152555  --  iteration [24/24]
# Epoch TRAIN [3/80]  -- Loss = 0.6673753795524439  --  iteration [96/96]
# Epoch TEST [3/80]  -- Loss = 0.6833496913313866  --  iteration [24/24]
# Epoch TRAIN [4/80]  -- Loss = 0.6633528753494223  --  iteration [96/96]
# Epoch TEST [4/80]  -- Loss = 0.681293822824955  --  iteration [24/24]]
# Epoch TRAIN [5/80]  -- Loss = 0.666012980354329  --  iteration [96/96]]
# Epoch TEST [5/80]  -- Loss = 0.6796302807827791  --  iteration [24/24]
# Epoch TRAIN [6/80]  -- Loss = 0.6568836808825532  --  iteration [96/96]
# Epoch TEST [6/80]  -- Loss = 0.6745409679909548  --  iteration [24/24]
# Epoch TRAIN [7/80]  -- Loss = 0.6543974122032523  --  iteration [96/96]
# Epoch TEST [7/80]  -- Loss = 0.6729546512166659  --  iteration [24/24]
# Epoch TRAIN [8/80]  -- Loss = 0.6462352617333332  --  iteration [96/96]
# Epoch TEST [8/80]  -- Loss = 0.6665885597467422  --  iteration [24/24]
# Epoch TRAIN [9/80]  -- Loss = 0.6486986676851908  --  iteration [96/96]
# Epoch TEST [9/80]  -- Loss = 0.6650177637736002  --  iteration [24/24]
# Epoch TRAIN [10/80]  -- Loss = 0.6409738364939889  --  iteration [96/96]
# Epoch TEST [10/80]  -- Loss = 0.6628392313917478  --  iteration [24/24]
# Epoch TRAIN [11/80]  -- Loss = 0.6353841507807374  --  iteration [96/96]
# Epoch TEST [11/80]  -- Loss = 0.6581666767597198  --  iteration [24/24]
# Epoch TRAIN [12/80]  -- Loss = 0.6373878459756573  --  iteration [96/96]
# Epoch TEST [12/80]  -- Loss = 0.6505352010329565  --  iteration [24/24]
# Epoch TRAIN [13/80]  -- Loss = 0.6311889747157693  --  iteration [96/96]
# Epoch TEST [13/80]  -- Loss = 0.6455314482251803  --  iteration [24/24]
# Epoch TRAIN [14/80]  -- Loss = 0.6256542140617967  --  iteration [96/96]
# Epoch TEST [14/80]  -- Loss = 0.639250905563434  --  iteration [24/24]]
# Epoch TRAIN [15/80]  -- Loss = 0.6234948287407557  --  iteration [96/96]
# Epoch TEST [15/80]  -- Loss = 0.6281219720840454  --  iteration [24/24]
# Epoch TRAIN [16/80]  -- Loss = 0.6164958231771985  --  iteration [96/96]
# Epoch TEST [16/80]  -- Loss = 0.6276179949442545  --  iteration [24/24]
# Epoch TRAIN [17/80]  -- Loss = 0.6039319252595305  --  iteration [96/96]
# Epoch TEST [17/80]  -- Loss = 0.617062916358312  --  iteration [24/24]]
# Epoch TRAIN [18/80]  -- Loss = 0.6101167344798645  --  iteration [96/96]
# Epoch TEST [18/80]  -- Loss = 0.6075536099572977  --  iteration [24/24]
# Epoch TRAIN [19/80]  -- Loss = 0.5980811982105175  --  iteration [96/96]
# Epoch TEST [19/80]  -- Loss = 0.586221964408954  --  iteration [24/24]]
# Epoch TRAIN [20/80]  -- Loss = 0.5917373557264606  --  iteration [96/96]
# Epoch TEST [20/80]  -- Loss = 0.5803474100927511  --  iteration [24/24]
# Epoch TRAIN [21/80]  -- Loss = 0.5803369591012597  --  iteration [96/96]
# Epoch TEST [21/80]  -- Loss = 0.5648212594290575  --  iteration [24/24]
# Epoch TRAIN [22/80]  -- Loss = 0.5702988440170884  --  iteration [96/96]
# Epoch TEST [22/80]  -- Loss = 0.5621884701152643  --  iteration [24/24]
# Epoch TRAIN [23/80]  -- Loss = 0.5665504311521848  --  iteration [96/96]
# Epoch TEST [23/80]  -- Loss = 0.5437228803833326  --  iteration [24/24]
# Epoch TRAIN [24/80]  -- Loss = 0.5542522765075167  --  iteration [96/96]
# Epoch TEST [24/80]  -- Loss = 0.542208481580019  --  iteration [24/24]]
# Epoch TRAIN [25/80]  -- Loss = 0.5413047686840097  --  iteration [96/96]
# Epoch TEST [25/80]  -- Loss = 0.5349018760025501  --  iteration [24/24]
# Epoch TRAIN [26/80]  -- Loss = 0.5484866785506407  --  iteration [96/96]
# Epoch TEST [26/80]  -- Loss = 0.5263341329991817  --  iteration [24/24]
# Epoch TRAIN [27/80]  -- Loss = 0.5338776394103965  --  iteration [96/96]
# Epoch TEST [27/80]  -- Loss = 0.5186497705678145  --  iteration [24/24]]
# Epoch TRAIN [28/80]  -- Loss = 0.534791884633402  --  iteration [96/96]]]
# Epoch TEST [28/80]  -- Loss = 0.5070825715859731  --  iteration [24/24]]
# Epoch TRAIN [29/80]  -- Loss = 0.5296123024697105  --  iteration [96/96]]
# Epoch TEST [29/80]  -- Loss = 0.5028592497110367  --  iteration [24/24]
# Epoch TRAIN [30/80]  -- Loss = 0.5177084002643824  --  iteration [96/96]
# Epoch TEST [30/80]  -- Loss = 0.5008849613368511  --  iteration [24/24]]
# Epoch TRAIN [31/80]  -- Loss = 0.5124849509447813  --  iteration [96/96]
# Epoch TEST [31/80]  -- Loss = 0.49707620839277905  --  iteration [24/24]
# Epoch TRAIN [32/80]  -- Loss = 0.5096327001228929  --  iteration [96/96]]
# Epoch TEST [32/80]  -- Loss = 0.4864971401790778  --  iteration [24/24]]
# Epoch TRAIN [33/80]  -- Loss = 0.49865136730174225  --  iteration [96/96]
# Epoch TEST [33/80]  -- Loss = 0.4765322543680668  --  iteration [24/24]]
# Epoch TRAIN [34/80]  -- Loss = 0.4891326806197564  --  iteration [96/96]]
# Epoch TEST [34/80]  -- Loss = 0.4765981311599414  --  iteration [24/24]]
# Epoch TRAIN [35/80]  -- Loss = 0.49114994642635185  --  iteration [96/96]
# Epoch TEST [35/80]  -- Loss = 0.46772216136256856  --  iteration [24/24]
# Epoch TRAIN [36/80]  -- Loss = 0.49400184070691466  --  iteration [96/96]
# Epoch TEST [36/80]  -- Loss = 0.4768740323682626  --  iteration [24/24]]
# Epoch TRAIN [37/80]  -- Loss = 0.4839047609517972  --  iteration [96/96]]
# Epoch TEST [37/80]  -- Loss = 0.47568318371971446  --  iteration [24/24]
# Epoch TRAIN [38/80]  -- Loss = 0.47225166981418926  --  iteration [96/96]
# Epoch TEST [38/80]  -- Loss = 0.4714290176828702  --  iteration [24/24]]
# Epoch TRAIN [39/80]  -- Loss = 0.4768927861005068  --  iteration [96/96]]
# Epoch TEST [39/80]  -- Loss = 0.4672386236488819  --  iteration [24/24]]
# Epoch TRAIN [40/80]  -- Loss = 0.4655144422625502  --  iteration [96/96]]
# Epoch TEST [40/80]  -- Loss = 0.4691658665736516  --  iteration [24/24]]
# Epoch TRAIN [41/80]  -- Loss = 0.4695741628917555  --  iteration [96/96]]
# Epoch TEST [41/80]  -- Loss = 0.467051283766826  --  iteration [24/24]4]
# Epoch TRAIN [42/80]  -- Loss = 0.45788593621303636  --  iteration [96/96]
# Epoch TEST [42/80]  -- Loss = 0.4654057373603185  --  iteration [24/24]]
# Epoch TRAIN [43/80]  -- Loss = 0.45745797362178564  --  iteration [96/96]
# Epoch TEST [43/80]  -- Loss = 0.4559240322560072  --  iteration [24/24]]
# Epoch TRAIN [44/80]  -- Loss = 0.45474425811941427  --  iteration [96/96]
# Epoch TEST [44/80]  -- Loss = 0.46155278322597343  --  iteration [24/24]
# Epoch TRAIN [45/80]  -- Loss = 0.4458399006786446  --  iteration [96/96]]
# Epoch TEST [45/80]  -- Loss = 0.4502629569421212  --  iteration [24/24]]
# Epoch TRAIN [46/80]  -- Loss = 0.4409359364459912  --  iteration [96/96]]
# Epoch TEST [46/80]  -- Loss = 0.45770373071233433  --  iteration [24/24]
# Epoch TRAIN [47/80]  -- Loss = 0.42791385234644014  --  iteration [96/96]
# Epoch TEST [47/80]  -- Loss = 0.45760326894621056  --  iteration [24/24]
# Epoch TRAIN [48/80]  -- Loss = 0.4235173451403777  --  iteration [96/96]]
# Epoch TEST [48/80]  -- Loss = 0.4527946449816227  --  iteration [24/24]]
# Epoch TRAIN [49/80]  -- Loss = 0.41834563699861366  --  iteration [96/96]
# Epoch TEST [49/80]  -- Loss = 0.44731246307492256  --  iteration [24/24]
# Epoch TRAIN [50/80]  -- Loss = 0.42802217323333025  --  iteration [96/96]
# Epoch TEST [50/80]  -- Loss = 0.453387384613355  --  iteration [24/24]]]
# Epoch TRAIN [51/80]  -- Loss = 0.4167361557483673  --  iteration [96/96]]
# Epoch TEST [51/80]  -- Loss = 0.4431956640134255  --  iteration [24/24]]
# Epoch TRAIN [52/80]  -- Loss = 0.4089208608493209  --  iteration [96/96]]
# Epoch TEST [52/80]  -- Loss = 0.44430399996538955  --  iteration [24/24]
# Epoch TRAIN [53/80]  -- Loss = 0.4096144017142554  --  iteration [96/96]]
# Epoch TEST [53/80]  -- Loss = 0.4469272308051586  --  iteration [24/24]]
# Epoch TRAIN [54/80]  -- Loss = 0.3880159519612789  --  iteration [96/96]]
# Epoch TEST [54/80]  -- Loss = 0.445895791053772  --  iteration [24/24]4]
# Epoch TRAIN [55/80]  -- Loss = 0.3893602869162957  --  iteration [96/96]]
# Epoch TEST [55/80]  -- Loss = 0.4519130482027928  --  iteration [24/24]]
# Epoch TRAIN [56/80]  -- Loss = 0.3819089125220974  --  iteration [96/96]]
# Epoch TEST [56/80]  -- Loss = 0.4485630722095569  --  iteration [24/24]]
# Epoch TRAIN [57/80]  -- Loss = 0.38482508428084355  --  iteration [96/96]
# Epoch TEST [57/80]  -- Loss = 0.4425409672160943  --  iteration [24/24]]
# Epoch TRAIN [58/80]  -- Loss = 0.3804478154828151  --  iteration [96/96]]
# Epoch TEST [58/80]  -- Loss = 0.4423226397484541  --  iteration [24/24]]
# Epoch TRAIN [59/80]  -- Loss = 0.3573980989555518  --  iteration [96/96]]
# Epoch TEST [59/80]  -- Loss = 0.44855795490245026  --  iteration [24/24]
# Epoch TRAIN [60/80]  -- Loss = 0.3506831411893169  --  iteration [96/96]]
# Epoch TEST [60/80]  -- Loss = 0.44464081587890786  --  iteration [24/24]
# Epoch TRAIN [61/80]  -- Loss = 0.33157157913471264  --  iteration [96/96]
# Epoch TEST [61/80]  -- Loss = 0.4411350345859925  --  iteration [24/24]]
# Epoch TRAIN [62/80]  -- Loss = 0.33535270346328616  --  iteration [96/96]
# Epoch TEST [62/80]  -- Loss = 0.44349974393844604  --  iteration [24/24]
# Epoch TRAIN [63/80]  -- Loss = 0.32726887248766917  --  iteration [96/96]
# Epoch TEST [63/80]  -- Loss = 0.4305447358638048  --  iteration [24/24]]
# Epoch TRAIN [64/80]  -- Loss = 0.3244428637747963  --  iteration [96/96]]
# Epoch TEST [64/80]  -- Loss = 0.4324839909871419  --  iteration [24/24]]
# Epoch TRAIN [65/80]  -- Loss = 0.32071036302174133  --  iteration [96/96]
# Epoch TEST [65/80]  -- Loss = 0.439447167639931  --  iteration [24/24]4]
# Epoch TRAIN [66/80]  -- Loss = 0.29937352892011404  --  iteration [96/96]
# Epoch TEST [66/80]  -- Loss = 0.4394522209962209  --  iteration [24/24]]
# Epoch TRAIN [67/80]  -- Loss = 0.2979612664785236  --  iteration [96/96]]
# Epoch TEST [67/80]  -- Loss = 0.431414345279336  --  iteration [24/24]]]
# Epoch TRAIN [68/80]  -- Loss = 0.28894800095198053  --  iteration [96/96]
# Epoch TEST [68/80]  -- Loss = 0.44581254354367655  --  iteration [24/24]
# Epoch TRAIN [69/80]  -- Loss = 0.2737618022753547  --  iteration [96/96]]
# Epoch TEST [69/80]  -- Loss = 0.43260452523827553  --  iteration [24/24]
# Epoch TRAIN [70/80]  -- Loss = 0.26527260593138635  --  iteration [96/96]
# Epoch TEST [70/80]  -- Loss = 0.44444692072769004  --  iteration [24/24]
# Epoch TRAIN [71/80]  -- Loss = 0.2571392645283292  --  iteration [96/96]]
# Epoch TEST [71/80]  -- Loss = 0.45460521740218  --  iteration [24/24]24]
# Epoch TRAIN [72/80]  -- Loss = 0.2411936322848002  --  iteration [96/96]]
# Epoch TEST [72/80]  -- Loss = 0.4402393040557702  --  iteration [24/24]]
# Epoch TRAIN [73/80]  -- Loss = 0.23141039938976368  --  iteration [96/96]
# Epoch TEST [73/80]  -- Loss = 0.4503982129196326  --  iteration [24/24]]
# Epoch TRAIN [74/80]  -- Loss = 0.23609997246724865  --  iteration [96/96]
# Epoch TEST [74/80]  -- Loss = 0.4463279191404581  --  iteration [24/24]]
# Epoch TRAIN [75/80]  -- Loss = 0.2268457867903635  --  iteration [96/96]]
# Epoch TEST [75/80]  -- Loss = 0.46288901443282765  --  iteration [24/24]
# Epoch TRAIN [76/80]  -- Loss = 0.21622179339950284  --  iteration [96/96]
# Epoch TEST [76/80]  -- Loss = 0.4606065784270565  --  iteration [24/24]]
# Epoch TRAIN [77/80]  -- Loss = 0.19738379935733974  --  iteration [96/96]
# Epoch TEST [77/80]  -- Loss = 0.46532371702293557  --  iteration [24/24]
# Epoch TRAIN [78/80]  -- Loss = 0.19784071164516112  --  iteration [96/96]
# Epoch TEST [78/80]  -- Loss = 0.4569087993974487  --  iteration [24/24]]
# Epoch TRAIN [79/80]  -- Loss = 0.1715980585819731  --  iteration [96/96]]
# Epoch TEST [79/80]  -- Loss = 0.452385055522124  --  iteration [24/24]]]
# Epoch TRAIN [80/80]  -- Loss = 0.17247990623582155  --  iteration [96/96]
# Epoch TEST [80/80]  -- Loss = 0.46298922784626484  --  iteration [24/24]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/80]  -- Loss = 0.707227660343051  --  iteration [96/96]]
# Epoch TEST [1/80]  -- Loss = 0.684912659227848  --  iteration [24/24]]
# Epoch TRAIN [2/80]  -- Loss = 0.6916693281382322  --  iteration [96/96]
# Epoch TEST [2/80]  -- Loss = 0.6829731042186419  --  iteration [24/24]
# Epoch TRAIN [3/80]  -- Loss = 0.6854206522305807  --  iteration [96/96]
# Epoch TEST [3/80]  -- Loss = 0.6794030070304871  --  iteration [24/24]
# Epoch TRAIN [4/80]  -- Loss = 0.6832039188593626  --  iteration [96/96]
# Epoch TEST [4/80]  -- Loss = 0.6768799771865209  --  iteration [24/24]
# Epoch TRAIN [5/80]  -- Loss = 0.6803956863780817  --  iteration [96/96]
# Epoch TEST [5/80]  -- Loss = 0.6722722401221594  --  iteration [24/24]
# Epoch TRAIN [6/80]  -- Loss = 0.6732118384291729  --  iteration [96/96]
# Epoch TEST [6/80]  -- Loss = 0.6707821413874626  --  iteration [24/24]
# Epoch TRAIN [7/80]  -- Loss = 0.6736449158440033  --  iteration [96/96]
# Epoch TEST [7/80]  -- Loss = 0.6662799889842669  --  iteration [24/24]
# Epoch TRAIN [8/80]  -- Loss = 0.6711182768146197  --  iteration [96/96]
# Epoch TEST [8/80]  -- Loss = 0.6628539065519968  --  iteration [24/24]
# Epoch TRAIN [9/80]  -- Loss = 0.6638895602275928  --  iteration [96/96]
# Epoch TEST [9/80]  -- Loss = 0.6574662104249  --  iteration [24/24]24]
# Epoch TRAIN [10/80]  -- Loss = 0.6598070325950781  --  iteration [96/96]
# Epoch TEST [10/80]  -- Loss = 0.6525422011812528  --  iteration [24/24]
# Epoch TRAIN [11/80]  -- Loss = 0.6555713545531034  --  iteration [96/96]
# Epoch TEST [11/80]  -- Loss = 0.647178848584493  --  iteration [24/24]]
# Epoch TRAIN [12/80]  -- Loss = 0.6515203329424063  --  iteration [96/96]
# Epoch TEST [12/80]  -- Loss = 0.6397987604141235  --  iteration [24/24]
# Epoch TRAIN [13/80]  -- Loss = 0.6416174539675316  --  iteration [96/96]
# Epoch TEST [13/80]  -- Loss = 0.6335297475258509  --  iteration [24/24]
# Epoch TRAIN [14/80]  -- Loss = 0.632640632490317  --  iteration [96/96]]
# Epoch TEST [14/80]  -- Loss = 0.6269668936729431  --  iteration [24/24]
# Epoch TRAIN [15/80]  -- Loss = 0.6208986857285103  --  iteration [96/96]
# Epoch TEST [15/80]  -- Loss = 0.6170432344079018  --  iteration [24/24]
# Epoch TRAIN [16/80]  -- Loss = 0.6131020579487085  --  iteration [96/96]
# Epoch TEST [16/80]  -- Loss = 0.604440006117026  --  iteration [24/24]]
# Epoch TRAIN [17/80]  -- Loss = 0.598152958167096  --  iteration [96/96]]
# Epoch TEST [17/80]  -- Loss = 0.5985704064369202  --  iteration [24/24]
# Epoch TRAIN [18/80]  -- Loss = 0.5883225587507089  --  iteration [96/96]
# Epoch TEST [18/80]  -- Loss = 0.5884277087946733  --  iteration [24/24]
# Epoch TRAIN [19/80]  -- Loss = 0.585005815140903  --  iteration [96/96]]
# Epoch TEST [19/80]  -- Loss = 0.582447831829389  --  iteration [24/24]]
# Epoch TRAIN [20/80]  -- Loss = 0.5707469061017036  --  iteration [96/96]
# Epoch TEST [20/80]  -- Loss = 0.5719418327013651  --  iteration [24/24]
# Epoch TRAIN [21/80]  -- Loss = 0.5517158390333256  --  iteration [96/96]
# Epoch TEST [21/80]  -- Loss = 0.5613141867021719  --  iteration [24/24]
# Epoch TRAIN [22/80]  -- Loss = 0.5342178950086236  --  iteration [96/96]
# Epoch TEST [22/80]  -- Loss = 0.5523105474809805  --  iteration [24/24]
# Epoch TRAIN [23/80]  -- Loss = 0.5234414528434476  --  iteration [96/96]
# Epoch TEST [23/80]  -- Loss = 0.5438007960716883  --  iteration [24/24]
# Epoch TRAIN [24/80]  -- Loss = 0.5152513850480318  --  iteration [96/96]]
# Epoch TEST [24/80]  -- Loss = 0.5381199146310488  --  iteration [24/24]
# Epoch TRAIN [25/80]  -- Loss = 0.4999832647542159  --  iteration [96/96]]
# Epoch TEST [25/80]  -- Loss = 0.5225139893591404  --  iteration [24/24]]
# Epoch TRAIN [26/80]  -- Loss = 0.48535557743161917  --  iteration [96/96]
# Epoch TEST [26/80]  -- Loss = 0.5227306733528773  --  iteration [24/24]
# Epoch TRAIN [27/80]  -- Loss = 0.46863715816289186  --  iteration [96/96]
# Epoch TEST [27/80]  -- Loss = 0.5249869028727213  --  iteration [24/24]
# Epoch TRAIN [28/80]  -- Loss = 0.4597084770600001  --  iteration [96/96]]
# Epoch TEST [28/80]  -- Loss = 0.5118071486552557  --  iteration [24/24]]
# Epoch TRAIN [29/80]  -- Loss = 0.44568474932263297  --  iteration [96/96]
# Epoch TEST [29/80]  -- Loss = 0.5287250640491644  --  iteration [24/24]
# Epoch TRAIN [30/80]  -- Loss = 0.43606587778776884  --  iteration [96/96]
# Epoch TEST [30/80]  -- Loss = 0.5114162464936575  --  iteration [24/24]
# Epoch TRAIN [31/80]  -- Loss = 0.4269265153755744  --  iteration [96/96]]
# Epoch TEST [31/80]  -- Loss = 0.5186770409345627  --  iteration [24/24]
# Epoch TRAIN [32/80]  -- Loss = 0.42119036180277664  --  iteration [96/96]
# Epoch TEST [32/80]  -- Loss = 0.5052575574566921  --  iteration [24/24]]
# Epoch TRAIN [33/80]  -- Loss = 0.4182572918944061  --  iteration [96/96]]
# Epoch TEST [33/80]  -- Loss = 0.5209578412274519  --  iteration [24/24]
# Epoch TRAIN [34/80]  -- Loss = 0.4041494151266913  --  iteration [96/96]]
# Epoch TEST [34/80]  -- Loss = 0.5240851988395056  --  iteration [24/24]
# Epoch TRAIN [35/80]  -- Loss = 0.3927804164898892  --  iteration [96/96]]
# Epoch TEST [35/80]  -- Loss = 0.5119291065881649  --  iteration [24/24]]
# Epoch TRAIN [36/80]  -- Loss = 0.3860263711151977  --  iteration [96/96]]
# Epoch TEST [36/80]  -- Loss = 0.5066029069324335  --  iteration [24/24]
# Epoch TRAIN [37/80]  -- Loss = 0.38028076213474077  --  iteration [96/96]
# Epoch TEST [37/80]  -- Loss = 0.5133190316458544  --  iteration [24/24]]
# Epoch TRAIN [38/80]  -- Loss = 0.37802682335798937  --  iteration [96/96]
# Epoch TEST [38/80]  -- Loss = 0.5350974090397358  --  iteration [24/24]
# Epoch TRAIN [39/80]  -- Loss = 0.377265106420964  --  iteration [96/96]]]
# Epoch TEST [39/80]  -- Loss = 0.5053768834720055  --  iteration [24/24]
# Epoch TRAIN [40/80]  -- Loss = 0.37694921841224033  --  iteration [96/96]
# Epoch TEST [40/80]  -- Loss = 0.5293499734252691  --  iteration [24/24]]
# Epoch TRAIN [41/80]  -- Loss = 0.3606117561769982  --  iteration [96/96]]
# Epoch TEST [41/80]  -- Loss = 0.5198819090922674  --  iteration [24/24]]
# Epoch TRAIN [42/80]  -- Loss = 0.34895841777324677  --  iteration [96/96]
# Epoch TEST [42/80]  -- Loss = 0.5043464861810207  --  iteration [24/24]]
# Epoch TRAIN [43/80]  -- Loss = 0.3451348029387494  --  iteration [96/96]]
# Epoch TEST [43/80]  -- Loss = 0.530970956509312  --  iteration [24/24]]
# Epoch TRAIN [44/80]  -- Loss = 0.34933525044471025  --  iteration [96/96]
# Epoch TEST [44/80]  -- Loss = 0.5217945128679276  --  iteration [24/24]]
# Epoch TRAIN [45/80]  -- Loss = 0.3375308602117002  --  iteration [96/96]]
# Epoch TEST [45/80]  -- Loss = 0.5359655736635128  --  iteration [24/24]
# Epoch TRAIN [46/80]  -- Loss = 0.3340439130552113  --  iteration [96/96]]
# Epoch TEST [46/80]  -- Loss = 0.527034449391067  --  iteration [24/24]]
# Epoch TRAIN [47/80]  -- Loss = 0.3325804735844334  --  iteration [96/96]]
# Epoch TEST [47/80]  -- Loss = 0.5348558866729339  --  iteration [24/24]
# Epoch TRAIN [48/80]  -- Loss = 0.318760386435315  --  iteration [96/96]6]
# Epoch TEST [48/80]  -- Loss = 0.5487349703907967  --  iteration [24/24]
# Epoch TRAIN [49/80]  -- Loss = 0.3323966827398787  --  iteration [96/96]]
# Epoch TEST [49/80]  -- Loss = 0.5377978775650263  --  iteration [24/24]]
# Epoch TRAIN [50/80]  -- Loss = 0.31340911231624585  --  iteration [96/96]
# Epoch TEST [50/80]  -- Loss = 0.5420451095948616  --  iteration [24/24]
# Epoch TRAIN [51/80]  -- Loss = 0.30211896542459726  --  iteration [96/96]
# Epoch TEST [51/80]  -- Loss = 0.5410044230520725  --  iteration [24/24]]
# Epoch TRAIN [52/80]  -- Loss = 0.293575391639024  --  iteration [96/96]
# Epoch TEST [52/80]  -- Loss = 0.5206659405181805  --  iteration [24/24]
# Epoch TRAIN [53/80]  -- Loss = 0.29378135630395263  --  iteration [96/96]
# Epoch TEST [53/80]  -- Loss = 0.5233382557829221  --  iteration [24/24]
# Epoch TRAIN [54/80]  -- Loss = 0.27713387249968946  --  iteration [96/96]
# Epoch TEST [54/80]  -- Loss = 0.5383331887423992  --  iteration [24/24]
# Epoch TRAIN [55/80]  -- Loss = 0.2824144357194503  --  iteration [96/96]]
# Epoch TEST [55/80]  -- Loss = 0.5560187076528867  --  iteration [24/24]]
# Epoch TRAIN [56/80]  -- Loss = 0.2941282529306288  --  iteration [96/96]]
# Epoch TEST [56/80]  -- Loss = 0.5243061936149994  --  iteration [24/24]
# Epoch TRAIN [57/80]  -- Loss = 0.2793422487253944  --  iteration [96/96]]
# Epoch TEST [57/80]  -- Loss = 0.555921065621078  --  iteration [24/24]]]
# Epoch TRAIN [58/80]  -- Loss = 0.25795418707032997  --  iteration [96/96]
# Epoch TEST [58/80]  -- Loss = 0.5415726558615764  --  iteration [24/24]]
# Epoch TRAIN [59/80]  -- Loss = 0.26676314099070925  --  iteration [96/96]
# Epoch TEST [59/80]  -- Loss = 0.5594130872438351  --  iteration [24/24]]
# Epoch TRAIN [60/80]  -- Loss = 0.25585582479834557  --  iteration [96/96]
# Epoch TEST [60/80]  -- Loss = 0.5446697926769654  --  iteration [24/24]]
# Epoch TRAIN [61/80]  -- Loss = 0.24102200761747858  --  iteration [96/96]
# Epoch TEST [61/80]  -- Loss = 0.5690748182435831  --  iteration [24/24]
# Epoch TRAIN [62/80]  -- Loss = 0.23005468413854638  --  iteration [96/96]
# Epoch TEST [62/80]  -- Loss = 0.5397603412469228  --  iteration [24/24]
# Epoch TRAIN [63/80]  -- Loss = 0.23613954436344406  --  iteration [96/96]
# Epoch TEST [63/80]  -- Loss = 0.5716956776256362  --  iteration [24/24]
# Epoch TRAIN [64/80]  -- Loss = 0.22450537098726878  --  iteration [96/96]
# Epoch TEST [64/80]  -- Loss = 0.5494879353791475  --  iteration [24/24]
# Epoch TRAIN [65/80]  -- Loss = 0.22060789489963403  --  iteration [96/96]
# Epoch TEST [65/80]  -- Loss = 0.5693531145031253  --  iteration [24/24]
# Epoch TRAIN [66/80]  -- Loss = 0.21367481847604117  --  iteration [96/96]
# Epoch TEST [66/80]  -- Loss = 0.5714070992544293  --  iteration [24/24]
# Epoch TRAIN [67/80]  -- Loss = 0.21061666550425193  --  iteration [96/96]
# Epoch TEST [67/80]  -- Loss = 0.5952023745824894  --  iteration [24/24]]
# Epoch TRAIN [68/80]  -- Loss = 0.20512755552772433  --  iteration [96/96]
# Epoch TEST [68/80]  -- Loss = 0.5765762835120162  --  iteration [24/24]
# Epoch TRAIN [69/80]  -- Loss = 0.18723570613656193  --  iteration [96/96]
# Epoch TEST [69/80]  -- Loss = 0.5748391821980476  --  iteration [24/24]]
# Epoch TRAIN [70/80]  -- Loss = 0.191281289444305  --  iteration [96/96]6]
# Epoch TEST [70/80]  -- Loss = 0.5919872143616279  --  iteration [24/24]
# Epoch TRAIN [71/80]  -- Loss = 0.18718769370267788  --  iteration [96/96]
# Epoch TEST [71/80]  -- Loss = 0.6053495189795891  --  iteration [24/24]
# Epoch TRAIN [72/80]  -- Loss = 0.1763478146167472  --  iteration [96/96]]
# Epoch TEST [72/80]  -- Loss = 0.5925374043484529  --  iteration [24/24]
# Epoch TRAIN [73/80]  -- Loss = 0.16922572253194326  --  iteration [96/96]
# Epoch TEST [73/80]  -- Loss = 0.5596813752005497  --  iteration [24/24]
# Epoch TRAIN [74/80]  -- Loss = 0.16514876545018828  --  iteration [96/96]
# Epoch TEST [74/80]  -- Loss = 0.6204622139533361  --  iteration [24/24]
# Epoch TRAIN [75/80]  -- Loss = 0.15922831691568717  --  iteration [96/96]
# Epoch TEST [75/80]  -- Loss = 0.6197113953530788  --  iteration [24/24]
# Epoch TRAIN [76/80]  -- Loss = 0.16066143820838383  --  iteration [96/96]
# Epoch TEST [76/80]  -- Loss = 0.5930806534985701  --  iteration [24/24]
# Epoch TRAIN [77/80]  -- Loss = 0.14996257179882377  --  iteration [96/96]
# Epoch TEST [77/80]  -- Loss = 0.6072847939406832  --  iteration [24/24]]
# Epoch TRAIN [78/80]  -- Loss = 0.15678276119676107  --  iteration [96/96]
# Epoch TEST [78/80]  -- Loss = 0.6118190189202627  --  iteration [24/24]
# Epoch TRAIN [79/80]  -- Loss = 0.1447253111594667  --  iteration [96/96]]
# Epoch TEST [79/80]  -- Loss = 0.6191227522989114  --  iteration [24/24]
# Epoch TRAIN [80/80]  -- Loss = 0.13171361908704662  --  iteration [96/96]
# Epoch TEST [80/80]  -- Loss = 0.6146660779292384  --  iteration [24/24]]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/80]  -- Loss = 0.7065954972058535  --  iteration [96/96]
# Epoch TEST [1/80]  -- Loss = 0.6915996347864469  --  iteration [24/24]
# Epoch TRAIN [2/80]  -- Loss = 0.6814883432040612  --  iteration [96/96]
# Epoch TEST [2/80]  -- Loss = 0.6587944179773331  --  iteration [24/24]
# Epoch TRAIN [3/80]  -- Loss = 0.6650747222205003  --  iteration [96/96]
# Epoch TEST [3/80]  -- Loss = 0.6418360968430837  --  iteration [24/24]
# Epoch TRAIN [4/80]  -- Loss = 0.6568322293460369  --  iteration [96/96]
# Epoch TEST [4/80]  -- Loss = 0.6292857105533282  --  iteration [24/24]
# Epoch TRAIN [5/80]  -- Loss = 0.6555872540920973  --  iteration [96/96]
# Epoch TEST [5/80]  -- Loss = 0.6218791827559471  --  iteration [24/24]
# Epoch TRAIN [6/80]  -- Loss = 0.6457232069224119  --  iteration [96/96]
# Epoch TEST [6/80]  -- Loss = 0.6141885754962763  --  iteration [24/24]
# Epoch TRAIN [7/80]  -- Loss = 0.64903149039795  --  iteration [96/96]6]
# Epoch TEST [7/80]  -- Loss = 0.6130462661385536  --  iteration [24/24]
# Epoch TRAIN [8/80]  -- Loss = 0.6463345050190886  --  iteration [96/96]
# Epoch TEST [8/80]  -- Loss = 0.6105275998512903  --  iteration [24/24]
# Epoch TRAIN [9/80]  -- Loss = 0.6418718496958414  --  iteration [96/96]
# Epoch TEST [9/80]  -- Loss = 0.6044264137744904  --  iteration [24/24]
# Epoch TRAIN [10/80]  -- Loss = 0.6377794202417135  --  iteration [96/96]
# Epoch TEST [10/80]  -- Loss = 0.601438776900371  --  iteration [24/24]]
# Epoch TRAIN [11/80]  -- Loss = 0.6407845616340637  --  iteration [96/96]
# Epoch TEST [11/80]  -- Loss = 0.6024765049417814  --  iteration [24/24]
# Epoch TRAIN [12/80]  -- Loss = 0.6344852518911163  --  iteration [96/96]
# Epoch TEST [12/80]  -- Loss = 0.596668541431427  --  iteration [24/24]]
# Epoch TRAIN [13/80]  -- Loss = 0.6332263372217616  --  iteration [96/96]
# Epoch TEST [13/80]  -- Loss = 0.5932749658823013  --  iteration [24/24]
# Epoch TRAIN [14/80]  -- Loss = 0.6336751002818346  --  iteration [96/96]
# Epoch TEST [14/80]  -- Loss = 0.5873364557822546  --  iteration [24/24]
# Epoch TRAIN [15/80]  -- Loss = 0.6269346925740441  --  iteration [96/96]
# Epoch TEST [15/80]  -- Loss = 0.5879996977746487  --  iteration [24/24]
# Epoch TRAIN [16/80]  -- Loss = 0.6181620697801312  --  iteration [96/96]
# Epoch TEST [16/80]  -- Loss = 0.5829056364794573  --  iteration [24/24]
# Epoch TRAIN [17/80]  -- Loss = 0.6117094758277138  --  iteration [96/96]
# Epoch TEST [17/80]  -- Loss = 0.5755492908259233  --  iteration [24/24]
# Epoch TRAIN [18/80]  -- Loss = 0.6150125196824471  --  iteration [96/96]
# Epoch TEST [18/80]  -- Loss = 0.5695670743783315  --  iteration [24/24]
# Epoch TRAIN [19/80]  -- Loss = 0.5957891130819917  --  iteration [96/96]
# Epoch TEST [19/80]  -- Loss = 0.5588863678276539  --  iteration [24/24]
# Epoch TRAIN [20/80]  -- Loss = 0.5878181401640177  --  iteration [96/96]
# Epoch TEST [20/80]  -- Loss = 0.5562481371064981  --  iteration [24/24]
# Epoch TRAIN [21/80]  -- Loss = 0.5812756108740965  --  iteration [96/96]
# Epoch TEST [21/80]  -- Loss = 0.545484121888876  --  iteration [24/24]]
# Epoch TRAIN [22/80]  -- Loss = 0.5707837427034974  --  iteration [96/96]
# Epoch TEST [22/80]  -- Loss = 0.5357873315612475  --  iteration [24/24]
# Epoch TRAIN [23/80]  -- Loss = 0.5533209058145682  --  iteration [96/96]
# Epoch TEST [23/80]  -- Loss = 0.5255225275953611  --  iteration [24/24]
# Epoch TRAIN [24/80]  -- Loss = 0.5439494640255967  --  iteration [96/96]
# Epoch TEST [24/80]  -- Loss = 0.5166282889743646  --  iteration [24/24]
# Epoch TRAIN [25/80]  -- Loss = 0.5317391191298763  --  iteration [96/96]
# Epoch TEST [25/80]  -- Loss = 0.5102907357116541  --  iteration [24/24]
# Epoch TRAIN [26/80]  -- Loss = 0.5218685921281576  --  iteration [96/96]
# Epoch TEST [26/80]  -- Loss = 0.5016871293385824  --  iteration [24/24]
# Epoch TRAIN [27/80]  -- Loss = 0.5061005832006534  --  iteration [96/96]]
# Epoch TEST [27/80]  -- Loss = 0.49210240443547565  --  iteration [24/24]
# Epoch TRAIN [28/80]  -- Loss = 0.4821988142405947  --  iteration [96/96]]
# Epoch TEST [28/80]  -- Loss = 0.47968661536773044  --  iteration [24/24]
# Epoch TRAIN [29/80]  -- Loss = 0.4765079797556003  --  iteration [96/96]]
# Epoch TEST [29/80]  -- Loss = 0.4692721975346406  --  iteration [24/24]]
# Epoch TRAIN [30/80]  -- Loss = 0.44944239283601445  --  iteration [96/96]
# Epoch TEST [30/80]  -- Loss = 0.45902950565020245  --  iteration [24/24]
# Epoch TRAIN [31/80]  -- Loss = 0.4530471333612998  --  iteration [96/96]]
# Epoch TEST [31/80]  -- Loss = 0.4611761271953583  --  iteration [24/24]]
# Epoch TRAIN [32/80]  -- Loss = 0.4416181690370043  --  iteration [96/96]
# Epoch TEST [32/80]  -- Loss = 0.4621860012412071  --  iteration [24/24]]
# Epoch TRAIN [33/80]  -- Loss = 0.43093939948206145  --  iteration [96/96]
# Epoch TEST [33/80]  -- Loss = 0.43748515595992404  --  iteration [24/24]
# Epoch TRAIN [34/80]  -- Loss = 0.43521631322801113  --  iteration [96/96]
# Epoch TEST [34/80]  -- Loss = 0.4336024386187394  --  iteration [24/24]]
# Epoch TRAIN [35/80]  -- Loss = 0.41574092488735914  --  iteration [96/96]
# Epoch TEST [35/80]  -- Loss = 0.4430924455324809  --  iteration [24/24]]
# Epoch TRAIN [36/80]  -- Loss = 0.4124365040721993  --  iteration [96/96]]
# Epoch TEST [36/80]  -- Loss = 0.4414360634982586  --  iteration [24/24]]
# Epoch TRAIN [37/80]  -- Loss = 0.4160004169680178  --  iteration [96/96]]
# Epoch TEST [37/80]  -- Loss = 0.4532579177369674  --  iteration [24/24]]
# Epoch TRAIN [38/80]  -- Loss = 0.3907249153902133  --  iteration [96/96]]
# Epoch TEST [38/80]  -- Loss = 0.45066100855668384  --  iteration [24/24]
# Epoch TRAIN [39/80]  -- Loss = 0.38113749073818326  --  iteration [96/96]
# Epoch TEST [39/80]  -- Loss = 0.4445002097636461  --  iteration [24/24]]
# Epoch TRAIN [40/80]  -- Loss = 0.3906682073138654  --  iteration [96/96]]
# Epoch TEST [40/80]  -- Loss = 0.43840310412148636  --  iteration [24/24]
# Epoch TRAIN [41/80]  -- Loss = 0.39046966858829063  --  iteration [96/96]
# Epoch TEST [41/80]  -- Loss = 0.4456614702939987  --  iteration [24/24]]
# Epoch TRAIN [42/80]  -- Loss = 0.3822019719518721  --  iteration [96/96]]
# Epoch TEST [42/80]  -- Loss = 0.4533293352772792  --  iteration [24/24]]
# Epoch TRAIN [43/80]  -- Loss = 0.36674225159610313  --  iteration [96/96]
# Epoch TEST [43/80]  -- Loss = 0.4462209139019251  --  iteration [24/24]]
# Epoch TRAIN [44/80]  -- Loss = 0.3756470913843562  --  iteration [96/96]]
# Epoch TEST [44/80]  -- Loss = 0.452131824567914  --  iteration [24/24]]]
# Epoch TRAIN [45/80]  -- Loss = 0.3632726344900827  --  iteration [96/96]]
# Epoch TEST [45/80]  -- Loss = 0.44902811261514824  --  iteration [24/24]
# Epoch TRAIN [46/80]  -- Loss = 0.3646147136266033  --  iteration [96/96]]
# Epoch TEST [46/80]  -- Loss = 0.40888787247240543  --  iteration [24/24]
# Epoch TRAIN [47/80]  -- Loss = 0.364869970207413  --  iteration [96/96]]]
# Epoch TEST [47/80]  -- Loss = 0.41474324464797974  --  iteration [24/24]
# Epoch TRAIN [48/80]  -- Loss = 0.36272298273009557  --  iteration [96/96]
# Epoch TEST [48/80]  -- Loss = 0.45663371371726197  --  iteration [24/24]
# Epoch TRAIN [49/80]  -- Loss = 0.342191101051867  --  iteration [96/96]6]
# Epoch TEST [49/80]  -- Loss = 0.43311242076257866  --  iteration [24/24]
# Epoch TRAIN [50/80]  -- Loss = 0.3454740072290103  --  iteration [96/96]]
# Epoch TEST [50/80]  -- Loss = 0.43710792747636634  --  iteration [24/24]
# Epoch TRAIN [51/80]  -- Loss = 0.3519770949302862  --  iteration [96/96]]
# Epoch TEST [51/80]  -- Loss = 0.4579320525129636  --  iteration [24/24]]
# Epoch TRAIN [52/80]  -- Loss = 0.33959417332274217  --  iteration [96/96]
# Epoch TEST [52/80]  -- Loss = 0.4267032959808906  --  iteration [24/24]]
# Epoch TRAIN [53/80]  -- Loss = 0.3463924447229753  --  iteration [96/96]]
# Epoch TEST [53/80]  -- Loss = 0.47485132329165936  --  iteration [24/24]
# Epoch TRAIN [54/80]  -- Loss = 0.3413710684981197  --  iteration [96/96]]
# Epoch TEST [54/80]  -- Loss = 0.4314063893010219  --  iteration [24/24]]
# Epoch TRAIN [55/80]  -- Loss = 0.3364200668875128  --  iteration [96/96]]
# Epoch TEST [55/80]  -- Loss = 0.46249532885849476  --  iteration [24/24]
# Epoch TRAIN [56/80]  -- Loss = 0.3348339277630051  --  iteration [96/96]]
# Epoch TEST [56/80]  -- Loss = 0.42909685460229713  --  iteration [24/24]
# Epoch TRAIN [57/80]  -- Loss = 0.3123472029498468  --  iteration [96/96]]
# Epoch TEST [57/80]  -- Loss = 0.42836731889595586  --  iteration [24/24]
# Epoch TRAIN [58/80]  -- Loss = 0.32473518947760266  --  iteration [96/96]
# Epoch TEST [58/80]  -- Loss = 0.43414450871447724  --  iteration [24/24]
# Epoch TRAIN [59/80]  -- Loss = 0.3069830706808716  --  iteration [96/96]]
# Epoch TEST [59/80]  -- Loss = 0.4408313259482384  --  iteration [24/24]]
# Epoch TRAIN [60/80]  -- Loss = 0.311783789889887  --  iteration [96/96]]]
# Epoch TEST [60/80]  -- Loss = 0.4284630222246051  --  iteration [24/24]]
# Epoch TRAIN [61/80]  -- Loss = 0.3101983704448988  --  iteration [96/96]]
# Epoch TEST [61/80]  -- Loss = 0.4782169641306003  --  iteration [24/24]]
# Epoch TRAIN [62/80]  -- Loss = 0.30700185677657527  --  iteration [96/96]
# Epoch TEST [62/80]  -- Loss = 0.42594887875020504  --  iteration [24/24]
# Epoch TRAIN [63/80]  -- Loss = 0.29939727888753015  --  iteration [96/96]
# Epoch TEST [63/80]  -- Loss = 0.4291060008108616  --  iteration [24/24]]
# Epoch TRAIN [64/80]  -- Loss = 0.28610237990505993  --  iteration [96/96]
# Epoch TEST [64/80]  -- Loss = 0.46721227404971916  --  iteration [24/24]
# Epoch TRAIN [65/80]  -- Loss = 0.2741803217989703  --  iteration [96/96]]
# Epoch TEST [65/80]  -- Loss = 0.425427067403992  --  iteration [24/24]]]
# Epoch TRAIN [66/80]  -- Loss = 0.26955228865457076  --  iteration [96/96]
# Epoch TEST [66/80]  -- Loss = 0.43010646228988964  --  iteration [24/24]
# Epoch TRAIN [67/80]  -- Loss = 0.26594827487133443  --  iteration [96/96]
# Epoch TEST [67/80]  -- Loss = 0.42889330442994833  --  iteration [24/24]
# Epoch TRAIN [68/80]  -- Loss = 0.24925697889799872  --  iteration [96/96]
# Epoch TEST [68/80]  -- Loss = 0.4674462356294195  --  iteration [24/24]]
# Epoch TRAIN [69/80]  -- Loss = 0.25967751804273576  --  iteration [96/96]
# Epoch TEST [69/80]  -- Loss = 0.4313863975306352  --  iteration [24/24]]
# Epoch TRAIN [70/80]  -- Loss = 0.2634853844841321  --  iteration [96/96]]
# Epoch TEST [70/80]  -- Loss = 0.48314918391406536  --  iteration [24/24]
# Epoch TRAIN [71/80]  -- Loss = 0.2548219052841887  --  iteration [96/96]]
# Epoch TEST [71/80]  -- Loss = 0.43711752134064835  --  iteration [24/24]
# Epoch TRAIN [72/80]  -- Loss = 0.24418958967241147  --  iteration [96/96]
# Epoch TEST [72/80]  -- Loss = 0.466575111883382  --  iteration [24/24]4]
# Epoch TRAIN [73/80]  -- Loss = 0.2422629065501193  --  iteration [96/96]]
# Epoch TEST [73/80]  -- Loss = 0.45457979415853816  --  iteration [24/24]
# Epoch TRAIN [74/80]  -- Loss = 0.24243873245238015  --  iteration [96/96]
# Epoch TEST [74/80]  -- Loss = 0.450654790426294  --  iteration [24/24]4]
# Epoch TRAIN [75/80]  -- Loss = 0.23329651557529965  --  iteration [96/96]
# Epoch TEST [75/80]  -- Loss = 0.4651996673395236  --  iteration [24/24]]
# Epoch TRAIN [76/80]  -- Loss = 0.22239797360574207  --  iteration [96/96]
# Epoch TEST [76/80]  -- Loss = 0.4286944754421711  --  iteration [24/24]]
# Epoch TRAIN [77/80]  -- Loss = 0.22591936922011277  --  iteration [96/96]
# Epoch TEST [77/80]  -- Loss = 0.43186062077681225  --  iteration [24/24]
# Epoch TRAIN [78/80]  -- Loss = 0.21463434654287994  --  iteration [96/96]
# Epoch TEST [78/80]  -- Loss = 0.44263743919630844  --  iteration [24/24]
# Epoch TRAIN [79/80]  -- Loss = 0.18829831259790808  --  iteration [96/96]
# Epoch TEST [79/80]  -- Loss = 0.4623512706408898  --  iteration [24/24]]
# Epoch TRAIN [80/80]  -- Loss = 0.19975141082735112  --  iteration [96/96]
# Epoch TEST [80/80]  -- Loss = 0.46401005424559116  --  iteration [24/24]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/80]  -- Loss = 0.6865893018742403  --  iteration [96/96]
# Epoch TEST [1/80]  -- Loss = 0.6689192205667496  --  iteration [24/24]
# Epoch TRAIN [2/80]  -- Loss = 0.6793716065585613  --  iteration [96/96]
# Epoch TEST [2/80]  -- Loss = 0.6588148946563402  --  iteration [24/24]
# Epoch TRAIN [3/80]  -- Loss = 0.6797046655168136  --  iteration [96/96]
# Epoch TEST [3/80]  -- Loss = 0.6520866230130196  --  iteration [24/24]
# Epoch TRAIN [4/80]  -- Loss = 0.6724689764281114  --  iteration [96/96]
# Epoch TEST [4/80]  -- Loss = 0.6465371325612068  --  iteration [24/24]
# Epoch TRAIN [5/80]  -- Loss = 0.669741140678525  --  iteration [96/96]]
# Epoch TEST [5/80]  -- Loss = 0.6396466543277105  --  iteration [24/24]
# Epoch TRAIN [6/80]  -- Loss = 0.6656267127643029  --  iteration [96/96]
# Epoch TEST [6/80]  -- Loss = 0.6311214019854864  --  iteration [24/24]
# Epoch TRAIN [7/80]  -- Loss = 0.6567689627408981  --  iteration [96/96]
# Epoch TEST [7/80]  -- Loss = 0.6227089663346609  --  iteration [24/24]
# Epoch TRAIN [8/80]  -- Loss = 0.6557482263694207  --  iteration [96/96]
# Epoch TEST [8/80]  -- Loss = 0.6139922514557838  --  iteration [24/24]
# Epoch TRAIN [9/80]  -- Loss = 0.6473286816229423  --  iteration [96/96]
# Epoch TEST [9/80]  -- Loss = 0.6106318930784861  --  iteration [24/24]
# Epoch TRAIN [10/80]  -- Loss = 0.6422038935124874  --  iteration [96/96]
# Epoch TEST [10/80]  -- Loss = 0.5970030923684438  --  iteration [24/24]
# Epoch TRAIN [11/80]  -- Loss = 0.6283499784767628  --  iteration [96/96]
# Epoch TEST [11/80]  -- Loss = 0.5846032003561655  --  iteration [24/24]
# Epoch TRAIN [12/80]  -- Loss = 0.6182255409657955  --  iteration [96/96]
# Epoch TEST [12/80]  -- Loss = 0.5826288138826689  --  iteration [24/24]
# Epoch TRAIN [13/80]  -- Loss = 0.607901236663262  --  iteration [96/96]]
# Epoch TEST [13/80]  -- Loss = 0.562201913446188  --  iteration [24/24]]
# Epoch TRAIN [14/80]  -- Loss = 0.5903655051564177  --  iteration [96/96]
# Epoch TEST [14/80]  -- Loss = 0.5586719599862894  --  iteration [24/24]
# Epoch TRAIN [15/80]  -- Loss = 0.5739335045218468  --  iteration [96/96]
# Epoch TEST [15/80]  -- Loss = 0.5410201363265514  --  iteration [24/24]
# Epoch TRAIN [16/80]  -- Loss = 0.5624463725835085  --  iteration [96/96]
# Epoch TEST [16/80]  -- Loss = 0.5281012840569019  --  iteration [24/24]
# Epoch TRAIN [17/80]  -- Loss = 0.5398530528570215  --  iteration [96/96]
# Epoch TEST [17/80]  -- Loss = 0.5229239041606585  --  iteration [24/24]
# Epoch TRAIN [18/80]  -- Loss = 0.5281257362415394  --  iteration [96/96]
# Epoch TEST [18/80]  -- Loss = 0.49342425912618637  --  iteration [24/24]
# Epoch TRAIN [19/80]  -- Loss = 0.44286828488111496  --  iteration [4/96]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 for i in range(2,11):
#       3     BM_Name = 'BM_merged2_'+str(int(i))
# ----> 4     model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
#
# File ~\Documents\PhD\CodesDatarmor\OSmOSEcodesV2\Functions\train_network.py:277, in TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
#     274 print('TRAINNING : ')
#     276 #Launch the training
# --> 277 loss_tab_train, loss_tab_test = train(device, model_ft, optimizer, num_epochs, train_loader, test_loader, weight, model_path, Version_name, ModelName)
#     279 print('DONE')
#     281 #%% Save Model
#     282 #save model
#
# File ~\Documents\PhD\CodesDatarmor\OSmOSEcodesV2\Functions\train_network.py:76, in train(device, model_ft, optimizer, num_epochs, train_loader, test_loader, weight, model_path, Version_name, ModelName)
#      74 optimizer.step()
#      75 #loss mean over the epoch
# ---> 76 loss_sum_train += loss.item()
#      77 PrintedLine = f"Epoch TRAIN [{epoch_p}/{num_epochs}]" + '  -- Loss = '+ str(loss_sum_train/ite) + '  --  ' + f"iteration [{ite}/{len(train_loader)}]"
#      78 sys.stdout.write('\r'+PrintedLine)
#
# KeyboardInterrupt:
