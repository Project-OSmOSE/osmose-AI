# %% [markdown]
# ## Import functions

# %%
import os 
import sys
import numpy as np
#os.chdir(os.path.join("/home/datawork-osmose/",'osmoseNotebooks_v0','source'))

with open('path_codes.txt') as f:
    codes_path = f.readlines()[0]
with open('path_osmose_dataset.txt') as f:
    path_osmose_dataset = f.readlines()[0]
with open('path_osmose_analysisAI.txt') as f:
    path_osmose_analysisAI = f.readlines()[0]
    
sys.path.append(os.path.join(codes_path))
#os.chdir(os.path.join(codes_path))

from use_network_functions import show_epoch_loss, set_epoch, load_model_hyperparameters 
from check_files_in_ai_folders import check_available_ai_tasks_benchmark_modeltrained
from apply_model_on_new_format_dataset import apply_model_on_new_format_dataset_main, plot_some_example

# %% [markdown]
# #### <span style="color:red">*Select task, benchmark and model to apply*</span>

# %%
Task_ID_Model = 'task_example_osmose_user'
BM_Name_Model = 'bm_example_osmose_user'
model_name_Model = 'm1'

# %% [markdown]
# ## Print Parameters
#
# #### <span style="color:blue">*JUST RUN CELL*</span>

# %%
parameters_Model = load_model_hyperparameters(path_osmose_analysisAI, Task_ID_Model, BM_Name_Model, model_name_Model)

for item in list(parameters_Model.keys()):
    print(item, ' : ', parameters_Model[item])
# Out:
# TrainsetRatio  :  0.9
# batch_size  :  10
# learning_rate  :  0.0001
# num_epochs  :  10
# shuffle  :  True
# use_pretrained  :  False
# input_data_format  :  audio
# nfft  :  [512, 512, 512]
# window_size  :  [512, 512, 512]
# overlap  :  [92, 92, 92, 92, 92, 92, 92, 92, 92, 92, 92]
# dynamic_min  :  [-20, -20, -20]
# dynamic_max  :  [20, 20, 20]
# scaling  :  ['spectrum', 'spectrum', 'spectrum']
# num_classes  :  1
# sample_rate  :  [250 250 250]
# dataset_ID_tab  :  ['BlueFinLibrary_ElephantIsland2013Aural'
#  'BlueFinLibrary_ElephantIsland2014' 'BlueFinLibrary_RossSea2014']
# Task_ID  :  task_example_osmose_user
# BM_Name  :  bm_example_osmose_user
# SplitName  :  split_for_eval_small
# model_name  :  m1
# architecture  :  CNN3_FC3
# index_dataset  :  2

# %% [markdown]
# #### <span style="color:red">*Select the task, benchmark, and datasplit to evaluate your model*</span>

# %%
Task_ID_Evaluation = 'task_example_osmose_user'
BM_Name_Evaluation = 'bm_example_osmose_user_apply_new_dataset'
SplitName_Evaluation = 'ALL_DATASET'# 'ALL_DATASET'#'split_for_eval_1'

# %% [markdown]
# #### <span style="color:red">*Parameters for model application*</span>

# %%
input_data_format = 'audio' #'audio' ou 'spectrogram'
# 'spectrogram' : use already computed spectrogram
# 'audio' : use .wav file, spectrogram will be computed iteratively

nfft = [512]
window_size = [512]
overlap = [92]


#Useless if input_data_format = 'spectrogram'
dynamic_min = [-20]
dynamic_max = [20]
scaling = ['spectrum'] # 'spectrum', 'density'

# %%
parameters_Evaluation = {'input_data_format':input_data_format, 'nfft':nfft, 'window_size':window_size, 'overlap':overlap, 'dynamic_min':dynamic_min, 'dynamic_max':dynamic_max, 'scaling':scaling,}

# %%
plot_some_example(path_osmose_dataset, path_osmose_analysisAI, Task_ID_Model, BM_Name_Model, model_name_Model, parameters_Model, Task_ID_Evaluation, BM_Name_Evaluation, SplitName_Evaluation, parameters_Evaluation)
# Out:
# Loading trained model ...
# Done

# %%
LabelsList, labels, outputs, dataset, filename = apply_model_on_new_format_dataset_main(path_osmose_dataset, path_osmose_analysisAI, Task_ID_Model, BM_Name_Model, model_name_Model, parameters_Model, Task_ID_Evaluation, BM_Name_Evaluation, SplitName_Evaluation, parameters_Evaluation)
# Out:
# Done
# Applying model on evaluation set ...
# 100%|██████████| 14386/14386 [04:18<00:00, 55.74it/s]

# %%
import matplotlib.pyplot as plt
from evaluation_metrics import ComputeEvaluationMetrics, plot_PR_curve, plot_ROC_curve, plot_DET_curve, plot_COST_curve, plot_4_curves
from tqdm import tqdm
import sklearn
    
Recall, Precision, FP_rate, TP_rate, FN_rate, NormalizedExpectedCost, ProbabilityCost, threshold_array = ComputeEvaluationMetrics(LabelsList, labels, outputs)
AUC = sklearn.metrics.auc(FP_rate, TP_rate)
print(dataset + ' : ')
print('NB files : ',len(outputs))
print('AUC : ',AUC)

plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plt.plot(Recall, Precision)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid()
plt.subplot(1,2,2)
plt.plot(FP_rate, TP_rate)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.grid()
plt.tight_layout()
# Out:
# ...
# NB files :  14386
# AUC :  0.8303272337513075

# %%
plt.figure(figsize=(18,3))

plt.plot(labels)
plt.plot(outputs)
plt.xlim([0,2000])
# Out:
# (0.0, 2000.0)
