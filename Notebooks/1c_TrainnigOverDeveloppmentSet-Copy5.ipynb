# %% [markdown]
# # Train the network on developpment set
#
#
# NB : faire un test sur le set d'evaluation avec quelques fichiers test avec des calculs de Precision, Recall, quelques spectros, les labels
#
# ## Import functions

# %% [markdown]
# #### <span style="color:red">*JUST RUN CELL*</span>

# %%
import os 
import sys
import numpy as np
#os.chdir(os.path.join("/home/datawork-osmose/",'osmoseNotebooks_v0','source'))

with open('path_codes.txt') as f:
    codes_path = f.readlines()[0]
os.chdir(os.path.join(codes_path))

from train_network import TrainNetwork_main, plot_examples_from_test
from launcher_datasetScale import list_datasets
from check_files_in_ai_folders import check_available_ai_tasks_bm, check_available_ai_datasplit, check_available_formats, check_available_ai_model

# %% [markdown]
# ## Selection of task, benchmark and datasplit

# %%
check_available_ai_tasks_bm()
# Out:
# /
# TaskTEST1/
#     BMTEST1_1/
#              Dataset used :  ['MPSU_ForestouHuella' 'MPSU_ForestouHuella_copy']
# Task_Glider_PBW_AnnotatorAnalysis/
#     BM_merged15/
#              Dataset used :  ['Glider']
#     BM_EXP/
#              Dataset used :  ['Glider']
#     Comp_BM_curves/
#     BM_merged6/
#              Dataset used :  ['Glider']
#     BM_merged2_2/
#              Dataset used :  ['Glider']
#     BM_merged2_3/
#              Dataset used :  ['Glider']
#     BM_merged2_4/
#              Dataset used :  ['Glider']
#     BM_merged2_5/
#              Dataset used :  ['Glider']
#     BM_merged2_6/
#              Dataset used :  ['Glider']
#     BM_merged2_7/
#              Dataset used :  ['Glider']
#     BM_merged2_8/
#              Dataset used :  ['Glider']
#     BM_merged8/
#              Dataset used :  ['Glider']
#     BM_merged10/
#              Dataset used :  ['Glider']
#     BM_merged12/
#              Dataset used :  ['Glider']
#     BM_merged14/
#              Dataset used :  ['Glider']
#     BM_merged2_9/
#              Dataset used :  ['Glider']
#     BM_merged2_10/
#              Dataset used :  ['Glider']
#     WeakLabelling_AllAnnotation/
#              Dataset used :  ['Glider']
#     BM_AN_Nassau/
#              Dataset used :  ['Glider']
#     BM_AN_Shanghai/
#              Dataset used :  ['Glider']
#     BM_AN_Civitavecchia/
#              Dataset used :  ['Glider']
#     BM_AN_Galveston/
#              Dataset used :  ['Glider']
#     BM_AN_Venice/
#              Dataset used :  ['Glider']
#     BM_AN_Fukuoka/
#              Dataset used :  ['Glider']
#     BM_AN_Naples/
#              Dataset used :  ['Glider']
#     BM_AN_Bridgetown/
#              Dataset used :  ['Glider']
#     BM_AN_Valletta/
#              Dataset used :  ['Glider']
#     BM_AN_Rostock/
#              Dataset used :  ['Glider']
#     BM_AN_Dubrovnik/
#              Dataset used :  ['Glider']
#     BM_AN_Mahahual/
#              Dataset used :  ['Glider']
#     BM_AN_Ensenada/
#              Dataset used :  ['Glider']
#     BM_AN_Tunis/
#              Dataset used :  ['Glider']
#     BM_AN_Funchal/
#              Dataset used :  ['Glider']
#     BM_AN_Tallinn/
#              Dataset used :  ['Glider']
#     BM_AN_Malaga/
#              Dataset used :  ['Glider']
#     BM_AN_Helsinki/
#              Dataset used :  ['Glider']
#     BM_AN_Valencia/
#              Dataset used :  ['Glider']
#     BM_FULL_EVAL/
#              Dataset used :  ['Glider']
#     BM_FULL_EVAL_long/
#              Dataset used :  ['Glider']
# Task_Test_Apocado_whistles/
#     BM_1/
#              Dataset used :  ['APOCADO_IROISE_C2D1_07072022']
# Task_Det_PBW/
#     TEST1/
#              Dataset used :  ['Dataset2015_AUS']
#     TRAIN_Glider/
#              Dataset used :  ['Glider']
#     TRAIN_Glider_long/
#              Dataset used :  ['Glider']
#     Train_multilabels_grouped15/
#              Dataset used :  ['Glider']
#     Train_mergeboths/
#              Dataset used :  ['Glider' 'Dataset2015_AUS']
# Task_DS_Miller/
#     All_BlueWhale/
#              Dataset used :  ['BlueFinLibrary_BallenyIslands2015'
#  'BlueFinLibrary_ElephantIsland2013Aural'
#  'BlueFinLibrary_ElephantIsland2014' 'BlueFinLibrary_Greenwich64S2015'
#  'BlueFinLibrary_MaudRise2014' 'BlueFinLibrary_RossSea2014'
#  'BlueFinLibrary_casey2014' 'BlueFinLibrary_casey2017'
#  'BlueFinLibrary_kerguelen2005' 'BlueFinLibrary_kerguelen2014'
#  'BlueFinLibrary_kerguelen2015']

# %%
Task_ID = 'Task_DS_Miller'
BM_Name = 'All_BlueWhale'

# %%
check_available_ai_datasplit(Task_ID, BM_Name)
# Out:
# Datasplits available in this task and this benchmark :
# info_datasplit/
#     split_for_eval_2/

# %%
SplitName = 'split_for_eval_2'

# %% [markdown]
# ## Check model
#
# Choose the name of your new model. If the name already exist, it will be overwrited.

# %%
check_available_ai_model(Task_ID, BM_Name)
# Out:
# Models available in this task and this benchmark :

# %%
Version_name = 'm1'

# %% [markdown]
# ## Check all spectrograms already available

# %%
check_available_formats(Task_ID, BM_Name)
# Out:
# _______________
# Dataset :  BlueFinLibrary_BallenyIslands2015
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_ElephantIsland2013Aural
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_ElephantIsland2014
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_Greenwich64S2015
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_MaudRise2014
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_RossSea2014
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      150_250
#          1024_512_95
#          adjustment_spectros
#      adjust_metadata.csv
#      50_250
#          512_512_92
# _______________
# Dataset :  BlueFinLibrary_casey2014
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_casey2017
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_kerguelen2005
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_kerguelen2014
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv
# _______________
# Dataset :  BlueFinLibrary_kerguelen2015
# Available Spectrogram Format (nfft_windowsize_overlap) :
#      50_250
#          512_512_92
#      adjust_metadata.csv

# %% [markdown]
# Enter the spectrogram format in the corresponding parameters.
# As list, to match with the list of dataset used in the benchmark (checked above).
#
# Example with 2 dataset :
# - ``nfft`` = [1024, 4096]
# - ``window_size`` = [1024, 1024]
# - ``overlap`` = [80, 50]
#
#
# It is also possible to use only .wav file as input, new spectrograms will be computed iteratively.
# In this case, please fill also some other parameters for the computation of the new spectrograms :
#
# Nb : The wavefiles are normalized one by one using "data = (data - np.mean(data)) / np.std(data)". The normalization from instruments values to get absolute pressure level will be add on the next version.
#
#
# - ``dynamic_min`` = [-40, -40]
# - ``dynamic_max`` = [40, 40]
# - ``scaling`` = ['spectrum', 'spectrum']

# %%
input_data_format = 'spectrogram' # 'audio'
# 'spectrogram' : use already computed spectrogram
# 'audio' : use .wav file, spectrogram will be computed iteratively

nfft = [512 for x in range(11)]
window_size = [512 for x in range(11)]
overlap = [92 for x in range(11)]


#Useless if input_data_format = 'spectrogram'
dynamic_min =  [-20 for x in range(11)]
dynamic_max =  [20for x in range(11)]
scaling =  ['spectrum' for x in range(11)] # 'spectrum', 'density'

# %% [markdown]
# ### Set model parameters
#
# #### <span style="color:green">*LIST OF PARAMETERS*</span>
#
# - `` ModelName `` : Architecture of the model. Please, select one in this list : (for more details, check : https://pytorch.org/vision/main/models.html)
#     - 'CNN3_FC1'
#     - 'CNN3_FC3'
#     - 'resnet18'
#     - 'resnet50'
#     - 'resnet101'
#     - 'vgg11'
#     - 'vgg11_bn'
#     - 'vgg13'
#     - 'vgg13_bn'
#     - 'vgg19'
#     - 'vgg19_bn'
#     - 'alexnet'
#
#
# - `` use_pretrained `` : (for more details, check : https://pytorch.org/vision/main/models.html) (By default : use_pretrained = True)
#     - True : if you want to used already pretrained network one reference image dataset and just finetun the last layer
#     - False : if you want to train your network from random weights and adjust all layers
#
#
#
# - `` TrainsetRatio `` : ratio between 0 and 1 of all the developpement set that will be used for the training (the oser part is for testing). (if None : TrainSetRatio = 0.9)
#
# - `` batch_size `` : Number of spectrograms per batch (if None : batch_size = 10)
# - `` learning_rate `` : step size at each iteration while moving toward a minimum of a loss function (if None : learning_rate = 1e-3)
# - `` num_epochs `` : Number of iteration over all developpement set (if None : num_epochs = 10)

# %%
ModelName = 'CNN4_FC3'
use_pretrained = False

TrainsetRatio = 0.9
batch_size = 20
learning_rate = 1e-4
num_epochs = 60
shuffle = 'True'

# %%
parameters = {'TrainsetRatio':TrainsetRatio, 'batch_size':batch_size, 'learning_rate':learning_rate, 'num_epochs':num_epochs, 'shuffle':shuffle, 'use_pretrained':use_pretrained, 'input_data_format':input_data_format, 'nfft':nfft, 'window_size':window_size, 'overlap':overlap, 'dynamic_min':dynamic_min, 'dynamic_max':dynamic_max, 'scaling':scaling}

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
# Out:
# MODEL INFORMATION :
#
# CNN4_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 conv4.0.weight
# 	 conv4.0.bias
# 	 conv4.1.weight
# 	 conv4.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6319114675699187  --  iteration [1210/1210]
# Epoch TEST [1/60]  -- Loss = 0.49898545510733305  --  iteration [134/134]
# Epoch TRAIN [2/60]  -- Loss = 0.5120644976900629  --  iteration [1210/1210]
# Epoch TEST [2/60]  -- Loss = 0.4341216713412484  --  iteration [134/134]]
# Epoch TRAIN [3/60]  -- Loss = 0.49182666702704  --  iteration [1210/1210]10]
# Epoch TEST [3/60]  -- Loss = 0.43040243703037945  --  iteration [134/134]
# Epoch TRAIN [4/60]  -- Loss = 0.47992440673930586  --  iteration [1210/1210]
# Epoch TEST [4/60]  -- Loss = 0.4287774825274055  --  iteration [134/134]]
# Epoch TRAIN [5/60]  -- Loss = 0.46778359925451357  --  iteration [1210/1210]
# Epoch TEST [5/60]  -- Loss = 0.43423749951284324  --  iteration [134/134]
# Epoch TRAIN [6/60]  -- Loss = 0.4597939144850762  --  iteration [1210/1210]]
# Epoch TEST [6/60]  -- Loss = 0.42756390438151004  --  iteration [134/134]
# Epoch TRAIN [7/60]  -- Loss = 0.44927197389366214  --  iteration [1210/1210]
# Epoch TEST [7/60]  -- Loss = 0.4270784147639773  --  iteration [134/134]]
# Epoch TRAIN [8/60]  -- Loss = 0.4420896682980632  --  iteration [1210/1210]]
# Epoch TEST [8/60]  -- Loss = 0.41609704917046564  --  iteration [134/134]
# Epoch TRAIN [9/60]  -- Loss = 0.43093201638745865  --  iteration [1210/1210]
# Epoch TEST [9/60]  -- Loss = 0.41240821200520245  --  iteration [134/134]
# Epoch TRAIN [10/60]  -- Loss = 0.4237307674136044  --  iteration [1210/1210]]
# Epoch TEST [10/60]  -- Loss = 0.38851085371935545  --  iteration [134/134]
# Epoch TRAIN [11/60]  -- Loss = 0.41445240858665183  --  iteration [1210/1210]
# Epoch TEST [11/60]  -- Loss = 0.37155766596100226  --  iteration [134/134]
# Epoch TRAIN [12/60]  -- Loss = 0.40538967936492165  --  iteration [1210/1210]
# Epoch TEST [12/60]  -- Loss = 0.3386729042699088  --  iteration [134/134]]
# Epoch TRAIN [13/60]  -- Loss = 0.39731044378901315  --  iteration [1210/1210]
# Epoch TEST [13/60]  -- Loss = 0.33107709139585495  --  iteration [134/134]
# Epoch TRAIN [14/60]  -- Loss = 0.3921673872869862  --  iteration [1210/1210]]
# Epoch TEST [14/60]  -- Loss = 0.3310819819791993  --  iteration [134/134]]
# Epoch TRAIN [15/60]  -- Loss = 0.3838142121133726  --  iteration [1210/1210]]
# Epoch TEST [15/60]  -- Loss = 0.30711748072905326  --  iteration [134/134]
# Epoch TRAIN [16/60]  -- Loss = 0.3786288086663593  --  iteration [1210/1210]]
# Epoch TEST [16/60]  -- Loss = 0.32062512536102267  --  iteration [134/134]
# Epoch TRAIN [17/60]  -- Loss = 0.37504523009800717  --  iteration [1210/1210]
# Epoch TEST [17/60]  -- Loss = 0.30840885883836605  --  iteration [134/134]
# Epoch TRAIN [18/60]  -- Loss = 0.371011017730906  --  iteration [1210/1210]0]
# Epoch TEST [18/60]  -- Loss = 0.2868106843375448  --  iteration [134/134]]
# Epoch TRAIN [19/60]  -- Loss = 0.3675785773179748  --  iteration [1210/1210]]
# Epoch TEST [19/60]  -- Loss = 0.2999151145566755  --  iteration [134/134]]
# Epoch TRAIN [20/60]  -- Loss = 0.36428536983314624  --  iteration [1210/1210]
# Epoch TEST [20/60]  -- Loss = 0.31211854194972055  --  iteration [134/134]
# Epoch TRAIN [21/60]  -- Loss = 0.360686539680012  --  iteration [1210/1210]0]
# Epoch TEST [21/60]  -- Loss = 0.2901429642937077  --  iteration [134/134]]
# Epoch TRAIN [22/60]  -- Loss = 0.35256115605762184  --  iteration [1210/1210]
# Epoch TEST [22/60]  -- Loss = 0.28503822857764227  --  iteration [134/134]
# Epoch TRAIN [23/60]  -- Loss = 0.348772001993065  --  iteration [1210/1210]]]
# Epoch TEST [23/60]  -- Loss = 0.2808393060938636  --  iteration [134/134]]
# Epoch TRAIN [24/60]  -- Loss = 0.3456522644058732  --  iteration [1210/1210]]
# Epoch TEST [24/60]  -- Loss = 0.2899575485333578  --  iteration [134/134]]
# Epoch TRAIN [25/60]  -- Loss = 0.34181362480417754  --  iteration [1210/1210]
# Epoch TEST [25/60]  -- Loss = 0.2694510575661908  --  iteration [134/134]]
# Epoch TRAIN [26/60]  -- Loss = 0.3385085825954587  --  iteration [1210/1210]]
# Epoch TEST [26/60]  -- Loss = 0.3062456985240552  --  iteration [134/134]]
# Epoch TRAIN [27/60]  -- Loss = 0.3326212174143673  --  iteration [1210/1210]]
# Epoch TEST [27/60]  -- Loss = 0.32988505443530297  --  iteration [134/134]
# Epoch TRAIN [28/60]  -- Loss = 0.32858060013410473  --  iteration [1210/1210]
# Epoch TEST [28/60]  -- Loss = 0.26822329434885905  --  iteration [134/134]

# %%
plot_examples_from_test(model_ft, test_loader, LabelsList)

# %%
AN_list = ['Nassau', 'Shanghai', 'Civitavecchia', 'Galveston', 'Venice', 'Fukuoka', 'Naples', 'Bridgetown', 'Valletta', 'Rostock', 'Dubrovnik', 'Mahahual', 'Ensenada', 'Tunis', 'Funchal', 'Tallinn','Malaga', 'Helsinki', 'Valencia']

for i in range(len(AN_list)):
    Task_ID = 'Task_Glider_PBW_AnnotatorAnalysis'

    BM_Name = 'BM_AN_'+AN_list[i]
    model_ft, test_loader, LabelsList = TrainNetwork_main(Task_ID, BM_Name, SplitName, Version_name, ModelName, parameters)
# Out:
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6587555084699466  --  iteration [81/81]
# Epoch TEST [1/60]  -- Loss = 0.6959883451461792  --  iteration [20/20]
# Epoch TRAIN [2/60]  -- Loss = 0.6570578986479912  --  iteration [81/81]
# Epoch TEST [2/60]  -- Loss = 0.6961575508117676  --  iteration [20/20]
# Epoch TRAIN [3/60]  -- Loss = 0.6544974059970291  --  iteration [81/81]
# Epoch TEST [3/60]  -- Loss = 0.6842590898275376  --  iteration [20/20]
# Epoch TRAIN [4/60]  -- Loss = 0.6471906024732708  --  iteration [81/81]
# Epoch TEST [4/60]  -- Loss = 0.6856823742389679  --  iteration [20/20]
# Epoch TRAIN [5/60]  -- Loss = 0.6412682687794721  --  iteration [81/81]
# Epoch TEST [5/60]  -- Loss = 0.6820358037948608  --  iteration [20/20]
# Epoch TRAIN [6/60]  -- Loss = 0.6327699466987893  --  iteration [81/81]
# Epoch TEST [6/60]  -- Loss = 0.6751656770706177  --  iteration [20/20]
# Epoch TRAIN [7/60]  -- Loss = 0.62948813924083  --  iteration [81/81]1]
# Epoch TEST [7/60]  -- Loss = 0.6693459033966065  --  iteration [20/20]
# Epoch TRAIN [8/60]  -- Loss = 0.6277054415808784  --  iteration [81/81]
# Epoch TEST [8/60]  -- Loss = 0.6549064010381699  --  iteration [20/20]
# Epoch TRAIN [9/60]  -- Loss = 0.6128907865948148  --  iteration [81/81]
# Epoch TEST [9/60]  -- Loss = 0.6390216290950775  --  iteration [20/20]
# Epoch TRAIN [10/60]  -- Loss = 0.6004191353733157  --  iteration [81/81]
# Epoch TEST [10/60]  -- Loss = 0.6408305555582047  --  iteration [20/20]
# Epoch TRAIN [11/60]  -- Loss = 0.5933092357935729  --  iteration [81/81]
# Epoch TEST [11/60]  -- Loss = 0.6262801140546799  --  iteration [20/20]
# Epoch TRAIN [12/60]  -- Loss = 0.5827135307553374  --  iteration [81/81]
# Epoch TEST [12/60]  -- Loss = 0.6135239765048027  --  iteration [20/20]
# Epoch TRAIN [13/60]  -- Loss = 0.5699001572750233  --  iteration [81/81]
# Epoch TEST [13/60]  -- Loss = 0.6045676708221436  --  iteration [20/20]
# Epoch TRAIN [14/60]  -- Loss = 0.5590022736125522  --  iteration [81/81]
# Epoch TEST [14/60]  -- Loss = 0.5914506211876869  --  iteration [20/20]
# Epoch TRAIN [15/60]  -- Loss = 0.5466714850914332  --  iteration [81/81]
# Epoch TEST [15/60]  -- Loss = 0.5884842798113823  --  iteration [20/20]
# Epoch TRAIN [16/60]  -- Loss = 0.5382702468354025  --  iteration [81/81]
# Epoch TEST [16/60]  -- Loss = 0.5743034794926644  --  iteration [20/20]
# Epoch TRAIN [17/60]  -- Loss = 0.5201767947938707  --  iteration [81/81]
# Epoch TEST [17/60]  -- Loss = 0.5650455564260483  --  iteration [20/20]
# Epoch TRAIN [18/60]  -- Loss = 0.5133095718460319  --  iteration [81/81]
# Epoch TEST [18/60]  -- Loss = 0.5527359321713448  --  iteration [20/20]
# Epoch TRAIN [19/60]  -- Loss = 0.5033846155360893  --  iteration [81/81]]
# Epoch TEST [19/60]  -- Loss = 0.5464568838477135  --  iteration [20/20]
# Epoch TRAIN [20/60]  -- Loss = 0.4899507724208596  --  iteration [81/81]]
# Epoch TEST [20/60]  -- Loss = 0.5327023640275002  --  iteration [20/20]
# Epoch TRAIN [21/60]  -- Loss = 0.4792977319455441  --  iteration [81/81]]
# Epoch TEST [21/60]  -- Loss = 0.5324903339147568  --  iteration [20/20]
# Epoch TRAIN [22/60]  -- Loss = 0.4676347054817058  --  iteration [81/81]]
# Epoch TEST [22/60]  -- Loss = 0.5172116875648498  --  iteration [20/20]
# Epoch TRAIN [23/60]  -- Loss = 0.4630319030932438  --  iteration [81/81]]
# Epoch TEST [23/60]  -- Loss = 0.5177711032330989  --  iteration [20/20]
# Epoch TRAIN [24/60]  -- Loss = 0.4641989791466866  --  iteration [81/81]]
# Epoch TEST [24/60]  -- Loss = 0.5220985688269139  --  iteration [20/20]
# Epoch TRAIN [25/60]  -- Loss = 0.4498359031147427  --  iteration [81/81]]
# Epoch TEST [25/60]  -- Loss = 0.5102439090609551  --  iteration [20/20]
# Epoch TRAIN [26/60]  -- Loss = 0.43779228186165847  --  iteration [81/81]
# Epoch TEST [26/60]  -- Loss = 0.5024615168571472  --  iteration [20/20]
# Epoch TRAIN [27/60]  -- Loss = 0.44519408764662566  --  iteration [81/81]
# Epoch TEST [27/60]  -- Loss = 0.5080598711967468  --  iteration [20/20]
# Epoch TRAIN [28/60]  -- Loss = 0.4170607133412067  --  iteration [81/81]]
# Epoch TEST [28/60]  -- Loss = 0.511138953268528  --  iteration [20/20]
# Epoch TRAIN [29/60]  -- Loss = 0.41991156026904963  --  iteration [81/81]
# Epoch TEST [29/60]  -- Loss = 0.5033937022089958  --  iteration [20/20]
# Epoch TRAIN [30/60]  -- Loss = 0.41190055509408313  --  iteration [81/81]
# Epoch TEST [30/60]  -- Loss = 0.5060212679207325  --  iteration [20/20]
# Epoch TRAIN [31/60]  -- Loss = 0.402073735072289  --  iteration [81/81]]]
# Epoch TEST [31/60]  -- Loss = 0.4890170067548752  --  iteration [20/20]
# Epoch TRAIN [32/60]  -- Loss = 0.3929632933419428  --  iteration [81/81]]
# Epoch TEST [32/60]  -- Loss = 0.5020809642970562  --  iteration [20/20]
# Epoch TRAIN [33/60]  -- Loss = 0.39212265077196523  --  iteration [81/81]
# Epoch TEST [33/60]  -- Loss = 0.5039178304374218  --  iteration [20/20]
# Epoch TRAIN [34/60]  -- Loss = 0.3897587279846639  --  iteration [81/81]]
# Epoch TEST [34/60]  -- Loss = 0.5020687207579613  --  iteration [20/20]
# Epoch TRAIN [35/60]  -- Loss = 0.37727636834721506  --  iteration [81/81]
# Epoch TEST [35/60]  -- Loss = 0.48798971697688104  --  iteration [20/20]
# Epoch TRAIN [36/60]  -- Loss = 0.37541567580199536  --  iteration [81/81]
# Epoch TEST [36/60]  -- Loss = 0.5038158416748046  --  iteration [20/20]
# Epoch TRAIN [37/60]  -- Loss = 0.3742151679816069  --  iteration [81/81]]
# Epoch TEST [37/60]  -- Loss = 0.5007704958319664  --  iteration [20/20]
# Epoch TRAIN [38/60]  -- Loss = 0.37083007726404404  --  iteration [81/81]
# Epoch TEST [38/60]  -- Loss = 0.5108247332274913  --  iteration [20/20]
# Epoch TRAIN [39/60]  -- Loss = 0.35557367349112473  --  iteration [81/81]
# Epoch TEST [39/60]  -- Loss = 0.5029953926801681  --  iteration [20/20]
# Epoch TRAIN [40/60]  -- Loss = 0.3493362378191065  --  iteration [81/81]]
# Epoch TEST [40/60]  -- Loss = 0.5092909142374993  --  iteration [20/20]
# Epoch TRAIN [41/60]  -- Loss = 0.3425298071937797  --  iteration [81/81]]
# Epoch TEST [41/60]  -- Loss = 0.5094112321734429  --  iteration [20/20]
# Epoch TRAIN [42/60]  -- Loss = 0.3371486007063477  --  iteration [81/81]]
# Epoch TEST [42/60]  -- Loss = 0.5076644860208035  --  iteration [20/20]
# Epoch TRAIN [43/60]  -- Loss = 0.32874591519803176  --  iteration [81/81]
# Epoch TEST [43/60]  -- Loss = 0.5100973889231681  --  iteration [20/20]
# Epoch TRAIN [44/60]  -- Loss = 0.32306901061976395  --  iteration [81/81]
# Epoch TEST [44/60]  -- Loss = 0.5115132562816143  --  iteration [20/20]
# Epoch TRAIN [45/60]  -- Loss = 0.3054610245205738  --  iteration [81/81]]
# Epoch TEST [45/60]  -- Loss = 0.5138464368879795  --  iteration [20/20]
# Epoch TRAIN [46/60]  -- Loss = 0.30954219005358075  --  iteration [81/81]
# Epoch TEST [46/60]  -- Loss = 0.5205938257277012  --  iteration [20/20]
# Epoch TRAIN [47/60]  -- Loss = 0.306297996253879  --  iteration [81/81]]]
# Epoch TEST [47/60]  -- Loss = 0.5115679003298282  --  iteration [20/20]
# Epoch TRAIN [48/60]  -- Loss = 0.30365446899776105  --  iteration [81/81]
# Epoch TEST [48/60]  -- Loss = 0.5163856953382492  --  iteration [20/20]
# Epoch TRAIN [49/60]  -- Loss = 0.29004254817594716  --  iteration [81/81]
# Epoch TEST [49/60]  -- Loss = 0.5182244397699833  --  iteration [20/20]
# Epoch TRAIN [50/60]  -- Loss = 0.27183018155671934  --  iteration [81/81]
# Epoch TEST [50/60]  -- Loss = 0.5052390448749066  --  iteration [20/20]
# Epoch TRAIN [51/60]  -- Loss = 0.27710158469868296  --  iteration [81/81]
# Epoch TEST [51/60]  -- Loss = 0.5230808705091476  --  iteration [20/20]
# Epoch TRAIN [52/60]  -- Loss = 0.27546152141359115  --  iteration [81/81]
# Epoch TEST [52/60]  -- Loss = 0.5362001352012158  --  iteration [20/20]
# Epoch TRAIN [53/60]  -- Loss = 0.250510138677962  --  iteration [81/81]]]
# Epoch TEST [53/60]  -- Loss = 0.5249315209686756  --  iteration [20/20]
# Epoch TRAIN [54/60]  -- Loss = 0.2590838302800685  --  iteration [81/81]]
# Epoch TEST [54/60]  -- Loss = 0.5350256215780973  --  iteration [20/20]
# Epoch TRAIN [55/60]  -- Loss = 0.24020909048892833  --  iteration [81/81]
# Epoch TEST [55/60]  -- Loss = 0.5237616211175918  --  iteration [20/20]
# Epoch TRAIN [56/60]  -- Loss = 0.23066738523818828  --  iteration [81/81]
# Epoch TEST [56/60]  -- Loss = 0.5189666591584683  --  iteration [20/20]
# Epoch TRAIN [57/60]  -- Loss = 0.22838454086471488  --  iteration [81/81]
# Epoch TEST [57/60]  -- Loss = 0.5396451562643051  --  iteration [20/20]
# Epoch TRAIN [58/60]  -- Loss = 0.22672824846741593  --  iteration [81/81]
# Epoch TEST [58/60]  -- Loss = 0.5312986850738526  --  iteration [20/20]
# Epoch TRAIN [59/60]  -- Loss = 0.21418061604102454  --  iteration [81/81]
# Epoch TEST [59/60]  -- Loss = 0.5488961488008499  --  iteration [20/20]
# Epoch TRAIN [60/60]  -- Loss = 0.21379769345124564  --  iteration [81/81]
# Epoch TEST [60/60]  -- Loss = 0.5358145967125892  --  iteration [20/20]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.7065446468499991  --  iteration [78/78]
# Epoch TEST [1/60]  -- Loss = 0.6945922061016685  --  iteration [19/19]
# Epoch TRAIN [2/60]  -- Loss = 0.6978725347763453  --  iteration [78/78]
# Epoch TEST [2/60]  -- Loss = 0.6943858328618502  --  iteration [19/19]
# Epoch TRAIN [3/60]  -- Loss = 0.6944428827518072  --  iteration [78/78]
# Epoch TEST [3/60]  -- Loss = 0.6959913059284812  --  iteration [19/19]
# Epoch TRAIN [4/60]  -- Loss = 0.6894478018467243  --  iteration [78/78]
# Epoch TEST [4/60]  -- Loss = 0.6953915075251931  --  iteration [19/19]
# Epoch TRAIN [5/60]  -- Loss = 0.6906288441939231  --  iteration [78/78]
# Epoch TEST [5/60]  -- Loss = 0.6968015244132594  --  iteration [19/19]
# Epoch TRAIN [6/60]  -- Loss = 0.6894718057070023  --  iteration [78/78]
# Epoch TEST [6/60]  -- Loss = 0.6965184023505763  --  iteration [19/19]
# Epoch TRAIN [7/60]  -- Loss = 0.6877904924062582  --  iteration [78/78]
# Epoch TEST [7/60]  -- Loss = 0.6942720350466276  --  iteration [19/19]
# Epoch TRAIN [8/60]  -- Loss = 0.6879862271822416  --  iteration [78/78]
# Epoch TEST [8/60]  -- Loss = 0.6955545795591254  --  iteration [19/19]
# Epoch TRAIN [9/60]  -- Loss = 0.6831052158123407  --  iteration [78/78]
# Epoch TEST [9/60]  -- Loss = 0.6931334922188207  --  iteration [19/19]
# Epoch TRAIN [10/60]  -- Loss = 0.6833977286632245  --  iteration [78/78]
# Epoch TEST [10/60]  -- Loss = 0.6893436563642401  --  iteration [19/19]
# Epoch TRAIN [11/60]  -- Loss = 0.6795972799643492  --  iteration [78/78]
# Epoch TEST [11/60]  -- Loss = 0.6866615100910789  --  iteration [19/19]
# Epoch TRAIN [12/60]  -- Loss = 0.6785085522211515  --  iteration [78/78]
# Epoch TEST [12/60]  -- Loss = 0.6855524276432238  --  iteration [19/19]
# Epoch TRAIN [13/60]  -- Loss = 0.6774221391249926  --  iteration [78/78]
# Epoch TEST [13/60]  -- Loss = 0.6811440712527225  --  iteration [19/19]
# Epoch TRAIN [14/60]  -- Loss = 0.6741546805088336  --  iteration [78/78]
# Epoch TEST [14/60]  -- Loss = 0.6796996718958804  --  iteration [19/19]
# Epoch TRAIN [15/60]  -- Loss = 0.6708172063032786  --  iteration [78/78]
# Epoch TEST [15/60]  -- Loss = 0.6773141653914201  --  iteration [19/19]
# Epoch TRAIN [16/60]  -- Loss = 0.6659607482262146  --  iteration [78/78]
# Epoch TEST [16/60]  -- Loss = 0.6727530077884072  --  iteration [19/19]
# Epoch TRAIN [17/60]  -- Loss = 0.6627399455278348  --  iteration [78/78]
# Epoch TEST [17/60]  -- Loss = 0.669475749919289  --  iteration [19/19]]
# Epoch TRAIN [18/60]  -- Loss = 0.6564815449408996  --  iteration [78/78]
# Epoch TEST [18/60]  -- Loss = 0.6597403821192289  --  iteration [19/19]
# Epoch TRAIN [19/60]  -- Loss = 0.651686816643446  --  iteration [78/78]]
# Epoch TEST [19/60]  -- Loss = 0.656202168841111  --  iteration [19/19]]
# Epoch TRAIN [20/60]  -- Loss = 0.6475580693819584  --  iteration [78/78]
# Epoch TEST [20/60]  -- Loss = 0.6512356275006345  --  iteration [19/19]
# Epoch TRAIN [21/60]  -- Loss = 0.6420804781791492  --  iteration [78/78]
# Epoch TEST [21/60]  -- Loss = 0.6387521938273781  --  iteration [19/19]
# Epoch TRAIN [22/60]  -- Loss = 0.6335306121752813  --  iteration [78/78]
# Epoch TEST [22/60]  -- Loss = 0.6323718867803875  --  iteration [19/19]
# Epoch TRAIN [23/60]  -- Loss = 0.6267247093029511  --  iteration [78/78]
# Epoch TEST [23/60]  -- Loss = 0.6298404649684304  --  iteration [19/19]
# Epoch TRAIN [24/60]  -- Loss = 0.6145206682192974  --  iteration [78/78]
# Epoch TEST [24/60]  -- Loss = 0.6150773449947959  --  iteration [19/19]
# Epoch TRAIN [25/60]  -- Loss = 0.6125757304521707  --  iteration [78/78]
# Epoch TEST [25/60]  -- Loss = 0.6080015238962675  --  iteration [19/19]
# Epoch TRAIN [26/60]  -- Loss = 0.5954602918563745  --  iteration [78/78]
# Epoch TEST [26/60]  -- Loss = 0.6015953750986802  --  iteration [19/19]
# Epoch TRAIN [27/60]  -- Loss = 0.5868613796356397  --  iteration [78/78]
# Epoch TEST [27/60]  -- Loss = 0.5882167722049513  --  iteration [19/19]
# Epoch TRAIN [28/60]  -- Loss = 0.5862796077361474  --  iteration [78/78]
# Epoch TEST [28/60]  -- Loss = 0.5834640452736303  --  iteration [19/19]
# Epoch TRAIN [29/60]  -- Loss = 0.5703341185282438  --  iteration [78/78]
# Epoch TEST [29/60]  -- Loss = 0.5709290253488641  --  iteration [19/19]
# Epoch TRAIN [30/60]  -- Loss = 0.5577020862927804  --  iteration [78/78]
# Epoch TEST [30/60]  -- Loss = 0.5665759522663919  --  iteration [19/19]
# Epoch TRAIN [31/60]  -- Loss = 0.5417120567499063  --  iteration [78/78]
# Epoch TEST [31/60]  -- Loss = 0.5576719782854381  --  iteration [19/19]
# Epoch TRAIN [32/60]  -- Loss = 0.527569592763216  --  iteration [78/78]]
# Epoch TEST [32/60]  -- Loss = 0.5537557131365726  --  iteration [19/19]
# Epoch TRAIN [33/60]  -- Loss = 0.5309627770613401  --  iteration [78/78]
# Epoch TEST [33/60]  -- Loss = 0.5431888417193764  --  iteration [19/19]
# Epoch TRAIN [34/60]  -- Loss = 0.5159177168821677  --  iteration [78/78]]
# Epoch TEST [34/60]  -- Loss = 0.5374335034897453  --  iteration [19/19]
# Epoch TRAIN [35/60]  -- Loss = 0.5051327936160259  --  iteration [78/78]
# Epoch TEST [35/60]  -- Loss = 0.5301989411052904  --  iteration [19/19]
# Epoch TRAIN [36/60]  -- Loss = 0.4866322389779947  --  iteration [78/78]]
# Epoch TEST [36/60]  -- Loss = 0.5181888577185179  --  iteration [19/19]]
# Epoch TRAIN [37/60]  -- Loss = 0.473892262730843  --  iteration [78/78]]]
# Epoch TEST [37/60]  -- Loss = 0.5225924582857835  --  iteration [19/19]
# Epoch TRAIN [38/60]  -- Loss = 0.47763176568043536  --  iteration [78/78]
# Epoch TEST [38/60]  -- Loss = 0.5177252457330102  --  iteration [19/19]
# Epoch TRAIN [39/60]  -- Loss = 0.47605796483082646  --  iteration [78/78]
# Epoch TEST [39/60]  -- Loss = 0.5142713361664822  --  iteration [19/19]
# Epoch TRAIN [40/60]  -- Loss = 0.45929439232135433  --  iteration [78/78]
# Epoch TEST [40/60]  -- Loss = 0.5143865488077465  --  iteration [19/19]
# Epoch TRAIN [41/60]  -- Loss = 0.4591409820012557  --  iteration [78/78]]
# Epoch TEST [41/60]  -- Loss = 0.516826425728045  --  iteration [19/19]]
# Epoch TRAIN [42/60]  -- Loss = 0.44427036627745015  --  iteration [78/78]
# Epoch TEST [42/60]  -- Loss = 0.5018761620709771  --  iteration [19/19]]
# Epoch TRAIN [43/60]  -- Loss = 0.4349468382887351  --  iteration [78/78]]
# Epoch TEST [43/60]  -- Loss = 0.52104662437188  --  iteration [19/19]9]
# Epoch TRAIN [44/60]  -- Loss = 0.43174139543985707  --  iteration [78/78]
# Epoch TEST [44/60]  -- Loss = 0.5030103435641841  --  iteration [19/19]]
# Epoch TRAIN [45/60]  -- Loss = 0.4374563888861583  --  iteration [78/78]]
# Epoch TEST [45/60]  -- Loss = 0.49963533564617757  --  iteration [19/19]
# Epoch TRAIN [46/60]  -- Loss = 0.4266897554580982  --  iteration [78/78]]
# Epoch TEST [46/60]  -- Loss = 0.5052725798205325  --  iteration [19/19]
# Epoch TRAIN [47/60]  -- Loss = 0.42523219340886825  --  iteration [78/78]
# Epoch TEST [47/60]  -- Loss = 0.5046211935971913  --  iteration [19/19]]
# Epoch TRAIN [48/60]  -- Loss = 0.401765254063484  --  iteration [78/78]8]
# Epoch TEST [48/60]  -- Loss = 0.5163258533728751  --  iteration [19/19]
# Epoch TRAIN [49/60]  -- Loss = 0.4131010805185025  --  iteration [78/78]
# Epoch TEST [49/60]  -- Loss = 0.5191006346752769  --  iteration [19/19]
# Epoch TRAIN [50/60]  -- Loss = 0.3944465540922605  --  iteration [78/78]]
# Epoch TEST [50/60]  -- Loss = 0.5041335405487763  --  iteration [19/19]
# Epoch TRAIN [51/60]  -- Loss = 0.4123517788755588  --  iteration [78/78]]
# Epoch TEST [51/60]  -- Loss = 0.4964969150329891  --  iteration [19/19]]
# Epoch TRAIN [52/60]  -- Loss = 0.404880610987162  --  iteration [78/78]]]
# Epoch TEST [52/60]  -- Loss = 0.5019530489256507  --  iteration [19/19]
# Epoch TRAIN [53/60]  -- Loss = 0.40171415874591243  --  iteration [78/78]
# Epoch TEST [53/60]  -- Loss = 0.4942548510275389  --  iteration [19/19]]
# Epoch TRAIN [54/60]  -- Loss = 0.3932434950883572  --  iteration [78/78]]
# Epoch TEST [54/60]  -- Loss = 0.5072731171783648  --  iteration [19/19]
# Epoch TRAIN [55/60]  -- Loss = 0.3760592289842092  --  iteration [78/78]]
# Epoch TEST [55/60]  -- Loss = 0.527561793201848  --  iteration [19/19]]
# Epoch TRAIN [56/60]  -- Loss = 0.38462251558517796  --  iteration [78/78]
# Epoch TEST [56/60]  -- Loss = 0.5284134322091153  --  iteration [19/19]
# Epoch TRAIN [57/60]  -- Loss = 0.381687027712663  --  iteration [78/78]]]
# Epoch TEST [57/60]  -- Loss = 0.5124692262003296  --  iteration [19/19]
# Epoch TRAIN [58/60]  -- Loss = 0.3765984187141443  --  iteration [78/78]]
# Epoch TEST [58/60]  -- Loss = 0.5017021337622091  --  iteration [19/19]
# Epoch TRAIN [59/60]  -- Loss = 0.3886447848799901  --  iteration [78/78]]
# Epoch TEST [59/60]  -- Loss = 0.5150203006832224  --  iteration [19/19]
# Epoch TRAIN [60/60]  -- Loss = 0.36155374348163605  --  iteration [78/78]
# Epoch TEST [60/60]  -- Loss = 0.5122957072759929  --  iteration [19/19]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6900897296362145  --  iteration [86/86]
# Epoch TEST [1/60]  -- Loss = 0.6865225036938986  --  iteration [21/21]
# Epoch TRAIN [2/60]  -- Loss = 0.6883830026138661  --  iteration [86/86]
# Epoch TEST [2/60]  -- Loss = 0.6837316751480103  --  iteration [21/21]
# Epoch TRAIN [3/60]  -- Loss = 0.6827003699402476  --  iteration [86/86]
# Epoch TEST [3/60]  -- Loss = 0.6840488343011766  --  iteration [21/21]
# Epoch TRAIN [4/60]  -- Loss = 0.677215322505596  --  iteration [86/86]]
# Epoch TEST [4/60]  -- Loss = 0.678640828246162  --  iteration [21/21]
# Epoch TRAIN [5/60]  -- Loss = 0.6692600603713545  --  iteration [86/86]
# Epoch TEST [5/60]  -- Loss = 0.6697247113500323  --  iteration [21/21]
# Epoch TRAIN [6/60]  -- Loss = 0.6686040225417115  --  iteration [86/86]
# Epoch TEST [6/60]  -- Loss = 0.6710247624488104  --  iteration [21/21]
# Epoch TRAIN [7/60]  -- Loss = 0.6652821447960166  --  iteration [86/86]
# Epoch TEST [7/60]  -- Loss = 0.6621806791850499  --  iteration [21/21]
# Epoch TRAIN [8/60]  -- Loss = 0.6554717677970265  --  iteration [86/86]
# Epoch TEST [8/60]  -- Loss = 0.6616214315096537  --  iteration [21/21]
# Epoch TRAIN [9/60]  -- Loss = 0.6532563144384429  --  iteration [86/86]
# Epoch TEST [9/60]  -- Loss = 0.6546291198049273  --  iteration [21/21]
# Epoch TRAIN [10/60]  -- Loss = 0.6432154095450113  --  iteration [86/86]
# Epoch TEST [10/60]  -- Loss = 0.6453263674463544  --  iteration [21/21]
# Epoch TRAIN [11/60]  -- Loss = 0.633542935515559  --  iteration [86/86]
# Epoch TEST [11/60]  -- Loss = 0.6388103422664461  --  iteration [21/21]
# Epoch TRAIN [12/60]  -- Loss = 0.6277322422626407  --  iteration [86/86]
# Epoch TEST [12/60]  -- Loss = 0.6286076136997768  --  iteration [21/21]
# Epoch TRAIN [13/60]  -- Loss = 0.6199770403462787  --  iteration [86/86]
# Epoch TEST [13/60]  -- Loss = 0.6199820211955479  --  iteration [21/21]
# Epoch TRAIN [14/60]  -- Loss = 0.6048875000587729  --  iteration [86/86]
# Epoch TEST [14/60]  -- Loss = 0.6082141002019247  --  iteration [21/21]
# Epoch TRAIN [15/60]  -- Loss = 0.5902523859295734  --  iteration [86/86]
# Epoch TEST [15/60]  -- Loss = 0.5979991782279241  --  iteration [21/21]
# Epoch TRAIN [16/60]  -- Loss = 0.5775308120389318  --  iteration [86/86]
# Epoch TEST [16/60]  -- Loss = 0.5852139790852865  --  iteration [21/21]
# Epoch TRAIN [17/60]  -- Loss = 0.5625622688337814  --  iteration [86/86]
# Epoch TEST [17/60]  -- Loss = 0.5774751603603363  --  iteration [21/21]
# Epoch TRAIN [18/60]  -- Loss = 0.5413144029850183  --  iteration [86/86]
# Epoch TEST [18/60]  -- Loss = 0.5686372121175131  --  iteration [21/21]
# Epoch TRAIN [19/60]  -- Loss = 0.5318414575831835  --  iteration [86/86]
# Epoch TEST [19/60]  -- Loss = 0.5603666177817753  --  iteration [21/21]
# Epoch TRAIN [20/60]  -- Loss = 0.5168346932461095  --  iteration [86/86]
# Epoch TEST [20/60]  -- Loss = 0.5534871986934117  --  iteration [21/21]
# Epoch TRAIN [21/60]  -- Loss = 0.5016266003597615  --  iteration [86/86]
# Epoch TEST [21/60]  -- Loss = 0.5511289465995062  --  iteration [21/21]
# Epoch TRAIN [22/60]  -- Loss = 0.4841004755607871  --  iteration [86/86]
# Epoch TEST [22/60]  -- Loss = 0.5409112998417446  --  iteration [21/21]
# Epoch TRAIN [23/60]  -- Loss = 0.4820408297832622  --  iteration [86/86]
# Epoch TEST [23/60]  -- Loss = 0.5435773049082074  --  iteration [21/21]
# Epoch TRAIN [24/60]  -- Loss = 0.4726359591234562  --  iteration [86/86]
# Epoch TEST [24/60]  -- Loss = 0.5408728505883899  --  iteration [21/21]
# Epoch TRAIN [25/60]  -- Loss = 0.4589968470986499  --  iteration [86/86]]
# Epoch TEST [25/60]  -- Loss = 0.5358101257256099  --  iteration [21/21]
# Epoch TRAIN [26/60]  -- Loss = 0.44362802976785704  --  iteration [86/86]
# Epoch TEST [26/60]  -- Loss = 0.5408780773480734  --  iteration [21/21]
# Epoch TRAIN [27/60]  -- Loss = 0.4407909850395003  --  iteration [86/86]]
# Epoch TEST [27/60]  -- Loss = 0.5392707784970602  --  iteration [21/21]
# Epoch TRAIN [28/60]  -- Loss = 0.4292851331275563  --  iteration [86/86]]
# Epoch TEST [28/60]  -- Loss = 0.5414493268444425  --  iteration [21/21]
# Epoch TRAIN [29/60]  -- Loss = 0.4420060761446177  --  iteration [86/86]]
# Epoch TEST [29/60]  -- Loss = 0.5516622705118996  --  iteration [21/21]
# Epoch TRAIN [30/60]  -- Loss = 0.4354832110016845  --  iteration [86/86]]
# Epoch TEST [30/60]  -- Loss = 0.560534234557833  --  iteration [21/21]
# Epoch TRAIN [31/60]  -- Loss = 0.42650807666224105  --  iteration [86/86]
# Epoch TEST [31/60]  -- Loss = 0.5469907692500523  --  iteration [21/21]
# Epoch TRAIN [32/60]  -- Loss = 0.41609430105187173  --  iteration [86/86]
# Epoch TEST [32/60]  -- Loss = 0.5393092660676866  --  iteration [21/21]
# Epoch TRAIN [33/60]  -- Loss = 0.40260007942831794  --  iteration [86/86]
# Epoch TEST [33/60]  -- Loss = 0.5553821587846393  --  iteration [21/21]
# Epoch TRAIN [34/60]  -- Loss = 0.3889948838325434  --  iteration [86/86]]
# Epoch TEST [34/60]  -- Loss = 0.5380422600678035  --  iteration [21/21]
# Epoch TRAIN [35/60]  -- Loss = 0.40995375933342204  --  iteration [86/86]
# Epoch TEST [35/60]  -- Loss = 0.5312553104900178  --  iteration [21/21]
# Epoch TRAIN [36/60]  -- Loss = 0.39591037534004037  --  iteration [86/86]
# Epoch TEST [36/60]  -- Loss = 0.5430567754166467  --  iteration [21/21]
# Epoch TRAIN [37/60]  -- Loss = 0.4056047178631605  --  iteration [86/86]
# Epoch TEST [37/60]  -- Loss = 0.5504239080917268  --  iteration [21/21]
# Epoch TRAIN [38/60]  -- Loss = 0.38798343944688174  --  iteration [86/86]
# Epoch TEST [38/60]  -- Loss = 0.5635787298281988  --  iteration [21/21]
# Epoch TRAIN [39/60]  -- Loss = 0.3751860444628915  --  iteration [86/86]]
# Epoch TEST [39/60]  -- Loss = 0.5473763147989908  --  iteration [21/21]
# Epoch TRAIN [40/60]  -- Loss = 0.38303460354028745  --  iteration [86/86]
# Epoch TEST [40/60]  -- Loss = 0.5277873135748363  --  iteration [21/21]
# Epoch TRAIN [41/60]  -- Loss = 0.3890370425096778  --  iteration [86/86]]
# Epoch TEST [41/60]  -- Loss = 0.5615774527901695  --  iteration [21/21]
# Epoch TRAIN [42/60]  -- Loss = 0.379905121617539  --  iteration [86/86]]]
# Epoch TEST [42/60]  -- Loss = 0.5534924559649967  --  iteration [21/21]
# Epoch TRAIN [43/60]  -- Loss = 0.3580818785311178  --  iteration [86/86]]
# Epoch TEST [43/60]  -- Loss = 0.5420222126302265  --  iteration [21/21]
# Epoch TRAIN [44/60]  -- Loss = 0.3563191324125889  --  iteration [86/86]
# Epoch TEST [44/60]  -- Loss = 0.5556131509088335  --  iteration [21/21]
# Epoch TRAIN [45/60]  -- Loss = 0.34299971821696257  --  iteration [86/86]
# Epoch TEST [45/60]  -- Loss = 0.5644203367687407  --  iteration [21/21]
# Epoch TRAIN [46/60]  -- Loss = 0.33834521611069523  --  iteration [86/86]
# Epoch TEST [46/60]  -- Loss = 0.5563310306696665  --  iteration [21/21]
# Epoch TRAIN [47/60]  -- Loss = 0.3438295965451141  --  iteration [86/86]]
# Epoch TEST [47/60]  -- Loss = 0.5614676539387021  --  iteration [21/21]
# Epoch TRAIN [48/60]  -- Loss = 0.33512930823273435  --  iteration [86/86]
# Epoch TEST [48/60]  -- Loss = 0.543485660638128  --  iteration [21/21]
# Epoch TRAIN [49/60]  -- Loss = 0.3446540959872479  --  iteration [86/86]]
# Epoch TEST [49/60]  -- Loss = 0.560602278936477  --  iteration [21/21]
# Epoch TRAIN [50/60]  -- Loss = 0.32628092083126997  --  iteration [86/86]
# Epoch TEST [50/60]  -- Loss = 0.5734989863066446  --  iteration [21/21]
# Epoch TRAIN [51/60]  -- Loss = 0.312985232403112  --  iteration [86/86]6]
# Epoch TEST [51/60]  -- Loss = 0.5678801721050626  --  iteration [21/21]
# Epoch TRAIN [52/60]  -- Loss = 0.3115972146218599  --  iteration [86/86]
# Epoch TEST [52/60]  -- Loss = 0.5868279713959921  --  iteration [21/21]
# Epoch TRAIN [53/60]  -- Loss = 0.30814295799233193  --  iteration [86/86]
# Epoch TEST [53/60]  -- Loss = 0.577480361575172  --  iteration [21/21]
# Epoch TRAIN [54/60]  -- Loss = 0.2938768129882424  --  iteration [86/86]]
# Epoch TEST [54/60]  -- Loss = 0.5921991623583294  --  iteration [21/21]
# Epoch TRAIN [55/60]  -- Loss = 0.28448471201713693  --  iteration [86/86]
# Epoch TEST [55/60]  -- Loss = 0.5887530261561984  --  iteration [21/21]
# Epoch TRAIN [56/60]  -- Loss = 0.29423248213390973  --  iteration [86/86]
# Epoch TEST [56/60]  -- Loss = 0.5839568291391645  --  iteration [21/21]
# Epoch TRAIN [57/60]  -- Loss = 0.2730481915695723  --  iteration [86/86]]
# Epoch TEST [57/60]  -- Loss = 0.5956501322133201  --  iteration [21/21]
# Epoch TRAIN [58/60]  -- Loss = 0.27582505613911984  --  iteration [86/86]
# Epoch TEST [58/60]  -- Loss = 0.6010997561471803  --  iteration [21/21]
# Epoch TRAIN [59/60]  -- Loss = 0.27434636921037076  --  iteration [86/86]
# Epoch TEST [59/60]  -- Loss = 0.5792920908757618  --  iteration [21/21]
# Epoch TRAIN [60/60]  -- Loss = 0.2610547381431557  --  iteration [86/86]
# Epoch TEST [60/60]  -- Loss = 0.5829018336676416  --  iteration [21/21]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6975062326381081  --  iteration [95/95]
# Epoch TEST [1/60]  -- Loss = 0.6960836312045222  --  iteration [23/23]
# Epoch TRAIN [2/60]  -- Loss = 0.6961026762661181  --  iteration [95/95]
# Epoch TEST [2/60]  -- Loss = 0.6943929273149242  --  iteration [23/23]
# Epoch TRAIN [3/60]  -- Loss = 0.6939738938682958  --  iteration [95/95]
# Epoch TEST [3/60]  -- Loss = 0.6921362669571586  --  iteration [23/23]
# Epoch TRAIN [4/60]  -- Loss = 0.695321355995379  --  iteration [95/95]]
# Epoch TEST [4/60]  -- Loss = 0.6900305644325588  --  iteration [23/23]
# Epoch TRAIN [5/60]  -- Loss = 0.6910888113473591  --  iteration [95/95]
# Epoch TEST [5/60]  -- Loss = 0.6906315813893857  --  iteration [23/23]
# Epoch TRAIN [6/60]  -- Loss = 0.6895562887191773  --  iteration [95/95]
# Epoch TEST [6/60]  -- Loss = 0.6895704295324243  --  iteration [23/23]
# Epoch TRAIN [7/60]  -- Loss = 0.689677946191085  --  iteration [95/95]]
# Epoch TEST [7/60]  -- Loss = 0.6885944578958594  --  iteration [23/23]
# Epoch TRAIN [8/60]  -- Loss = 0.6884285625658537  --  iteration [95/95]
# Epoch TEST [8/60]  -- Loss = 0.6875415962675343  --  iteration [23/23]
# Epoch TRAIN [9/60]  -- Loss = 0.685866840262162  --  iteration [95/95]
# Epoch TEST [9/60]  -- Loss = 0.6874376354010209  --  iteration [23/23]
# Epoch TRAIN [10/60]  -- Loss = 0.6869347741729335  --  iteration [95/95]
# Epoch TEST [10/60]  -- Loss = 0.6865825316180354  --  iteration [23/23]
# Epoch TRAIN [11/60]  -- Loss = 0.684442653154072  --  iteration [95/95]]
# Epoch TEST [11/60]  -- Loss = 0.685881249282671  --  iteration [23/23]
# Epoch TRAIN [12/60]  -- Loss = 0.6838964073281539  --  iteration [95/95]
# Epoch TEST [12/60]  -- Loss = 0.6845888106719308  --  iteration [23/23]
# Epoch TRAIN [13/60]  -- Loss = 0.6819573904338636  --  iteration [95/95]
# Epoch TEST [13/60]  -- Loss = 0.6828877796297488  --  iteration [23/23]
# Epoch TRAIN [14/60]  -- Loss = 0.6791645909610547  --  iteration [95/95]
# Epoch TEST [14/60]  -- Loss = 0.6810624469881472  --  iteration [23/23]
# Epoch TRAIN [15/60]  -- Loss = 0.6777333391340156  --  iteration [95/95]
# Epoch TEST [15/60]  -- Loss = 0.6797528396482053  --  iteration [23/23]
# Epoch TRAIN [16/60]  -- Loss = 0.6768543350069146  --  iteration [95/95]
# Epoch TEST [16/60]  -- Loss = 0.6779058109159055  --  iteration [23/23]
# Epoch TRAIN [17/60]  -- Loss = 0.6753078266193993  --  iteration [95/95]
# Epoch TEST [17/60]  -- Loss = 0.674766833367555  --  iteration [23/23]
# Epoch TRAIN [18/60]  -- Loss = 0.6732192070860612  --  iteration [95/95]
# Epoch TEST [18/60]  -- Loss = 0.6730118342067885  --  iteration [23/23]
# Epoch TRAIN [19/60]  -- Loss = 0.6724865925939459  --  iteration [95/95]
# Epoch TEST [19/60]  -- Loss = 0.6701344692188761  --  iteration [23/23]
# Epoch TRAIN [20/60]  -- Loss = 0.6694710078992342  --  iteration [95/95]
# Epoch TEST [20/60]  -- Loss = 0.6682775979456694  --  iteration [23/23]
# Epoch TRAIN [21/60]  -- Loss = 0.6641985786588569  --  iteration [95/95]
# Epoch TEST [21/60]  -- Loss = 0.6658042228740194  --  iteration [23/23]
# Epoch TRAIN [22/60]  -- Loss = 0.6614052628215991  --  iteration [95/95]
# Epoch TEST [22/60]  -- Loss = 0.6602452190025992  --  iteration [23/23]
# Epoch TRAIN [23/60]  -- Loss = 0.6575541088455602  --  iteration [95/95]
# Epoch TEST [23/60]  -- Loss = 0.6566977189934772  --  iteration [23/23]
# Epoch TRAIN [24/60]  -- Loss = 0.6530581568416797  --  iteration [95/95]
# Epoch TEST [24/60]  -- Loss = 0.6520231780798539  --  iteration [23/23]
# Epoch TRAIN [25/60]  -- Loss = 0.6478639565016094  --  iteration [95/95]
# Epoch TEST [25/60]  -- Loss = 0.6476224531298098  --  iteration [23/23]
# Epoch TRAIN [26/60]  -- Loss = 0.6422103605772319  --  iteration [95/95]
# Epoch TEST [26/60]  -- Loss = 0.6374028454656187  --  iteration [23/23]
# Epoch TRAIN [27/60]  -- Loss = 0.6326232345480668  --  iteration [95/95]
# Epoch TEST [27/60]  -- Loss = 0.6317233754240948  --  iteration [23/23]
# Epoch TRAIN [28/60]  -- Loss = 0.6336166281449167  --  iteration [95/95]
# Epoch TEST [28/60]  -- Loss = 0.6246896178826041  --  iteration [23/23]
# Epoch TRAIN [29/60]  -- Loss = 0.619176079097547  --  iteration [95/95]]
# Epoch TEST [29/60]  -- Loss = 0.6157292956891267  --  iteration [23/23]
# Epoch TRAIN [30/60]  -- Loss = 0.6102954061407792  --  iteration [95/95]
# Epoch TEST [30/60]  -- Loss = 0.6063393756099369  --  iteration [23/23]
# Epoch TRAIN [31/60]  -- Loss = 0.5989384431588022  --  iteration [95/95]
# Epoch TEST [31/60]  -- Loss = 0.5943641766257908  --  iteration [23/23]
# Epoch TRAIN [32/60]  -- Loss = 0.5884336954668948  --  iteration [95/95]
# Epoch TEST [32/60]  -- Loss = 0.5866846597712972  --  iteration [23/23]
# Epoch TRAIN [33/60]  -- Loss = 0.5799475440853521  --  iteration [95/95]
# Epoch TEST [33/60]  -- Loss = 0.578807709009751  --  iteration [23/23]]
# Epoch TRAIN [34/60]  -- Loss = 0.5571258199842353  --  iteration [95/95]
# Epoch TEST [34/60]  -- Loss = 0.5655458712059519  --  iteration [23/23]
# Epoch TRAIN [35/60]  -- Loss = 0.5514788790753014  --  iteration [95/95]
# Epoch TEST [35/60]  -- Loss = 0.5486930466216543  --  iteration [23/23]
# Epoch TRAIN [36/60]  -- Loss = 0.5368502714132007  --  iteration [95/95]
# Epoch TEST [36/60]  -- Loss = 0.5462076132712157  --  iteration [23/23]
# Epoch TRAIN [37/60]  -- Loss = 0.5227372279292659  --  iteration [95/95]
# Epoch TEST [37/60]  -- Loss = 0.535783078359521  --  iteration [23/23]]
# Epoch TRAIN [38/60]  -- Loss = 0.5168169115719042  --  iteration [95/95]
# Epoch TEST [38/60]  -- Loss = 0.5329919975736866  --  iteration [23/23]
# Epoch TRAIN [39/60]  -- Loss = 0.5044012891618829  --  iteration [95/95]
# Epoch TEST [39/60]  -- Loss = 0.5258551473202913  --  iteration [23/23]
# Epoch TRAIN [40/60]  -- Loss = 0.49144187255909566  --  iteration [95/95]
# Epoch TEST [40/60]  -- Loss = 0.5210880961107172  --  iteration [23/23]
# Epoch TRAIN [41/60]  -- Loss = 0.48578464922152065  --  iteration [95/95]
# Epoch TEST [41/60]  -- Loss = 0.51124801972638  --  iteration [23/23]3]]
# Epoch TRAIN [42/60]  -- Loss = 0.46917198488586825  --  iteration [95/95]
# Epoch TEST [42/60]  -- Loss = 0.5093946865071421  --  iteration [23/23]]
# Epoch TRAIN [43/60]  -- Loss = 0.4605271010022414  --  iteration [95/95]]
# Epoch TEST [43/60]  -- Loss = 0.5065793187721915  --  iteration [23/23]
# Epoch TRAIN [44/60]  -- Loss = 0.4497660450245205  --  iteration [95/95]]
# Epoch TEST [44/60]  -- Loss = 0.499529718056969  --  iteration [23/23]]]
# Epoch TRAIN [45/60]  -- Loss = 0.43475497255199835  --  iteration [95/95]
# Epoch TEST [45/60]  -- Loss = 0.4930911485267722  --  iteration [23/23]]
# Epoch TRAIN [46/60]  -- Loss = 0.4330356190079137  --  iteration [95/95]]
# Epoch TEST [46/60]  -- Loss = 0.49869363398655603  --  iteration [23/23]
# Epoch TRAIN [47/60]  -- Loss = 0.4295097191082804  --  iteration [95/95]]
# Epoch TEST [47/60]  -- Loss = 0.5083569936130358  --  iteration [23/23]
# Epoch TRAIN [48/60]  -- Loss = 0.40794095506793576  --  iteration [95/95]
# Epoch TEST [48/60]  -- Loss = 0.4955552019502806  --  iteration [23/23]
# Epoch TRAIN [49/60]  -- Loss = 0.4258138262911847  --  iteration [95/95]
# Epoch TEST [49/60]  -- Loss = 0.4983078630074211  --  iteration [23/23]
# Epoch TRAIN [50/60]  -- Loss = 0.3952017173955315  --  iteration [95/95]]
# Epoch TEST [50/60]  -- Loss = 0.46172501146793365  --  iteration [23/23]
# Epoch TRAIN [51/60]  -- Loss = 0.40480386442259736  --  iteration [95/95]
# Epoch TEST [51/60]  -- Loss = 0.4966271066147348  --  iteration [23/23]]
# Epoch TRAIN [52/60]  -- Loss = 0.39793243314090526  --  iteration [95/95]
# Epoch TEST [52/60]  -- Loss = 0.48670564527096954  --  iteration [23/23]
# Epoch TRAIN [53/60]  -- Loss = 0.39289655356030717  --  iteration [95/95]
# Epoch TEST [53/60]  -- Loss = 0.4661514260198759  --  iteration [23/23]]
# Epoch TRAIN [54/60]  -- Loss = 0.37921176897852044  --  iteration [95/95]
# Epoch TEST [54/60]  -- Loss = 0.4845306484595589  --  iteration [23/23]]
# Epoch TRAIN [55/60]  -- Loss = 0.3754746421387321  --  iteration [95/95]]
# Epoch TEST [55/60]  -- Loss = 0.49414869235909503  --  iteration [23/23]
# Epoch TRAIN [56/60]  -- Loss = 0.3702037345421942  --  iteration [95/95]]
# Epoch TEST [56/60]  -- Loss = 0.4826942300019057  --  iteration [23/23]]
# Epoch TRAIN [57/60]  -- Loss = 0.3511014982273704  --  iteration [95/95]]
# Epoch TEST [57/60]  -- Loss = 0.4713479241599207  --  iteration [23/23]
# Epoch TRAIN [58/60]  -- Loss = 0.355743246251031  --  iteration [95/95]]]
# Epoch TEST [58/60]  -- Loss = 0.5114566243213156  --  iteration [23/23]]
# Epoch TRAIN [59/60]  -- Loss = 0.3454232615859885  --  iteration [95/95]]
# Epoch TEST [59/60]  -- Loss = 0.4864559205977813  --  iteration [23/23]]
# Epoch TRAIN [60/60]  -- Loss = 0.33391169168447193  --  iteration [95/95]
# Epoch TEST [60/60]  -- Loss = 0.5068715752466865  --  iteration [23/23]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6942964574869941  --  iteration [85/85]
# Epoch TEST [1/60]  -- Loss = 0.681733508904775  --  iteration [21/21]
# Epoch TRAIN [2/60]  -- Loss = 0.6849492949597976  --  iteration [85/85]
# Epoch TEST [2/60]  -- Loss = 0.675397447177342  --  iteration [21/21]
# Epoch TRAIN [3/60]  -- Loss = 0.6794754785649917  --  iteration [85/85]
# Epoch TEST [3/60]  -- Loss = 0.6705041925112406  --  iteration [21/21]
# Epoch TRAIN [4/60]  -- Loss = 0.6721867806771222  --  iteration [85/85]
# Epoch TEST [4/60]  -- Loss = 0.6679445448375884  --  iteration [21/21]
# Epoch TRAIN [5/60]  -- Loss = 0.6652384989401874  --  iteration [85/85]
# Epoch TEST [5/60]  -- Loss = 0.6589414448965163  --  iteration [21/21]
# Epoch TRAIN [6/60]  -- Loss = 0.6573963382664849  --  iteration [85/85]
# Epoch TEST [6/60]  -- Loss = 0.6570115827378773  --  iteration [21/21]
# Epoch TRAIN [7/60]  -- Loss = 0.6483195634449229  --  iteration [85/85]
# Epoch TEST [7/60]  -- Loss = 0.650848754814693  --  iteration [21/21]
# Epoch TRAIN [8/60]  -- Loss = 0.6494825980242561  --  iteration [85/85]
# Epoch TEST [8/60]  -- Loss = 0.6417751312255859  --  iteration [21/21]
# Epoch TRAIN [9/60]  -- Loss = 0.6366212879910188  --  iteration [85/85]
# Epoch TEST [9/60]  -- Loss = 0.6353499520392645  --  iteration [21/21]
# Epoch TRAIN [10/60]  -- Loss = 0.6317714670125176  --  iteration [85/85]
# Epoch TEST [10/60]  -- Loss = 0.6250014219965253  --  iteration [21/21]
# Epoch TRAIN [11/60]  -- Loss = 0.6226271524148829  --  iteration [85/85]
# Epoch TEST [11/60]  -- Loss = 0.6136930386225382  --  iteration [21/21]
# Epoch TRAIN [12/60]  -- Loss = 0.6121039278366986  --  iteration [85/85]
# Epoch TEST [12/60]  -- Loss = 0.6060529578299749  --  iteration [21/21]
# Epoch TRAIN [13/60]  -- Loss = 0.5944787740707398  --  iteration [85/85]
# Epoch TEST [13/60]  -- Loss = 0.5906054718153817  --  iteration [21/21]
# Epoch TRAIN [14/60]  -- Loss = 0.5894955151221332  --  iteration [85/85]
# Epoch TEST [14/60]  -- Loss = 0.5800709341253553  --  iteration [21/21]
# Epoch TRAIN [15/60]  -- Loss = 0.5713570387924418  --  iteration [85/85]
# Epoch TEST [15/60]  -- Loss = 0.571552962064743  --  iteration [21/21]
# Epoch TRAIN [16/60]  -- Loss = 0.5588416110066806  --  iteration [85/85]
# Epoch TEST [16/60]  -- Loss = 0.5635423106806619  --  iteration [21/21]
# Epoch TRAIN [17/60]  -- Loss = 0.548997197081061  --  iteration [85/85]]
# Epoch TEST [17/60]  -- Loss = 0.5488374219054267  --  iteration [21/21]
# Epoch TRAIN [18/60]  -- Loss = 0.5391382336616516  --  iteration [85/85]
# Epoch TEST [18/60]  -- Loss = 0.5435045475051516  --  iteration [21/21]
# Epoch TRAIN [19/60]  -- Loss = 0.5156448402825524  --  iteration [85/85]
# Epoch TEST [19/60]  -- Loss = 0.5244877480325245  --  iteration [21/21]
# Epoch TRAIN [20/60]  -- Loss = 0.4963227976770962  --  iteration [85/85]]
# Epoch TEST [20/60]  -- Loss = 0.5214786728223165  --  iteration [21/21]
# Epoch TRAIN [21/60]  -- Loss = 0.49255202552851507  --  iteration [85/85]
# Epoch TEST [21/60]  -- Loss = 0.5122453400066921  --  iteration [21/21]
# Epoch TRAIN [22/60]  -- Loss = 0.4845842552535674  --  iteration [85/85]]
# Epoch TEST [22/60]  -- Loss = 0.4965294102827708  --  iteration [21/21]
# Epoch TRAIN [23/60]  -- Loss = 0.4651518355397617  --  iteration [85/85]]
# Epoch TEST [23/60]  -- Loss = 0.4984845973196484  --  iteration [21/21]
# Epoch TRAIN [24/60]  -- Loss = 0.4628829672056086  --  iteration [85/85]]
# Epoch TEST [24/60]  -- Loss = 0.5022644996643066  --  iteration [21/21]
# Epoch TRAIN [25/60]  -- Loss = 0.4428166789167068  --  iteration [85/85]]
# Epoch TEST [25/60]  -- Loss = 0.501402613662538  --  iteration [21/21]
# Epoch TRAIN [26/60]  -- Loss = 0.45269004614914166  --  iteration [85/85]
# Epoch TEST [26/60]  -- Loss = 0.4853079815705617  --  iteration [21/21]
# Epoch TRAIN [27/60]  -- Loss = 0.4506270690875895  --  iteration [85/85]]
# Epoch TEST [27/60]  -- Loss = 0.4946333028021313  --  iteration [21/21]
# Epoch TRAIN [28/60]  -- Loss = 0.4331108734888189  --  iteration [85/85]]
# Epoch TEST [28/60]  -- Loss = 0.4896634802931831  --  iteration [21/21]
# Epoch TRAIN [29/60]  -- Loss = 0.430563449158388  --  iteration [85/85]]]
# Epoch TEST [29/60]  -- Loss = 0.49353419670036863  --  iteration [21/21]
# Epoch TRAIN [30/60]  -- Loss = 0.4290583298486822  --  iteration [85/85]]
# Epoch TEST [30/60]  -- Loss = 0.5035090176832109  --  iteration [21/21]
# Epoch TRAIN [31/60]  -- Loss = 0.42467617339947644  --  iteration [85/85]
# Epoch TEST [31/60]  -- Loss = 0.5118572406825566  --  iteration [21/21]
# Epoch TRAIN [32/60]  -- Loss = 0.42672090530395507  --  iteration [85/85]
# Epoch TEST [32/60]  -- Loss = 0.48704433299246286  --  iteration [21/21]
# Epoch TRAIN [33/60]  -- Loss = 0.41520122692865485  --  iteration [85/85]
# Epoch TEST [33/60]  -- Loss = 0.5052635612941924  --  iteration [21/21]
# Epoch TRAIN [34/60]  -- Loss = 0.40181761454133424  --  iteration [85/85]
# Epoch TEST [34/60]  -- Loss = 0.49518980724470957  --  iteration [21/21]
# Epoch TRAIN [35/60]  -- Loss = 0.3999823873533922  --  iteration [85/85]]
# Epoch TEST [35/60]  -- Loss = 0.4930388828118642  --  iteration [21/21]
# Epoch TRAIN [36/60]  -- Loss = 0.38360803916173825  --  iteration [85/85]
# Epoch TEST [36/60]  -- Loss = 0.4908031253587632  --  iteration [21/21]
# Epoch TRAIN [37/60]  -- Loss = 0.3846839666366577  --  iteration [85/85]]
# Epoch TEST [37/60]  -- Loss = 0.4885217320351374  --  iteration [21/21]
# Epoch TRAIN [38/60]  -- Loss = 0.367612285824383  --  iteration [85/85]5]
# Epoch TEST [38/60]  -- Loss = 0.50386862102009  --  iteration [21/21]  ]
# Epoch TRAIN [39/60]  -- Loss = 0.36064438311492697  --  iteration [85/85]
# Epoch TEST [39/60]  -- Loss = 0.4949291242020471  --  iteration [21/21]
# Epoch TRAIN [40/60]  -- Loss = 0.36879505970898796  --  iteration [85/85]
# Epoch TEST [40/60]  -- Loss = 0.4922427535057068  --  iteration [21/21]
# Epoch TRAIN [41/60]  -- Loss = 0.3627474618308684  --  iteration [85/85]]
# Epoch TEST [41/60]  -- Loss = 0.49384150263809024  --  iteration [21/21]
# Epoch TRAIN [42/60]  -- Loss = 0.3454378445358837  --  iteration [85/85]]
# Epoch TEST [42/60]  -- Loss = 0.5228990820192155  --  iteration [21/21]
# Epoch TRAIN [43/60]  -- Loss = 0.34733341827112085  --  iteration [85/85]
# Epoch TEST [43/60]  -- Loss = 0.49649422119061154  --  iteration [21/21]
# Epoch TRAIN [44/60]  -- Loss = 0.34418238226105186  --  iteration [85/85]
# ...
# Epoch TEST [22/60]  -- Loss = 0.5610501714374708  --  iteration [23/23]
# Epoch TRAIN [23/60]  -- Loss = 0.5644912207904069  --  iteration [92/92]
# Epoch TEST [23/60]  -- Loss = 0.5469623713389687  --  iteration [23/23]
# Epoch TRAIN [24/60]  -- Loss = 0.5462107088254846  --  iteration [92/92]
# Epoch TEST [24/60]  -- Loss = 0.5378226106581481  --  iteration [23/23]
# Epoch TRAIN [25/60]  -- Loss = 0.5337870052975157  --  iteration [92/92]
# Epoch TEST [25/60]  -- Loss = 0.519865896390832  --  iteration [23/23]
# Epoch TRAIN [26/60]  -- Loss = 0.5173642240140749  --  iteration [92/92]
# Epoch TEST [26/60]  -- Loss = 0.5069671752660171  --  iteration [23/23]
# Epoch TRAIN [27/60]  -- Loss = 0.49170761911765387  --  iteration [92/92]
# Epoch TEST [27/60]  -- Loss = 0.5009094632190206  --  iteration [23/23]]
# Epoch TRAIN [28/60]  -- Loss = 0.4885233971087829  --  iteration [92/92]]
# Epoch TEST [28/60]  -- Loss = 0.49018718367037567  --  iteration [23/23]
# Epoch TRAIN [29/60]  -- Loss = 0.4867083997182224  --  iteration [92/92]
# Epoch TEST [29/60]  -- Loss = 0.47976851074591925  --  iteration [23/23]
# Epoch TRAIN [30/60]  -- Loss = 0.4668369618770869  --  iteration [92/92]
# Epoch TEST [30/60]  -- Loss = 0.47296304417693097  --  iteration [23/23]
# Epoch TRAIN [31/60]  -- Loss = 0.4518333730166373  --  iteration [92/92]
# Epoch TEST [31/60]  -- Loss = 0.467686657672343  --  iteration [23/23]
# Epoch TRAIN [32/60]  -- Loss = 0.44451054412385693  --  iteration [92/92]
# Epoch TEST [32/60]  -- Loss = 0.4606653847124266  --  iteration [23/23]]
# Epoch TRAIN [33/60]  -- Loss = 0.4355134157382924  --  iteration [92/92]
# Epoch TEST [33/60]  -- Loss = 0.46021190803983936  --  iteration [23/23]
# Epoch TRAIN [34/60]  -- Loss = 0.4347931587177774  --  iteration [92/92]]
# Epoch TEST [34/60]  -- Loss = 0.457261482010717  --  iteration [23/23]]]
# Epoch TRAIN [35/60]  -- Loss = 0.41502174249161844  --  iteration [92/92]
# Epoch TEST [35/60]  -- Loss = 0.447721673094708  --  iteration [23/23]
# Epoch TRAIN [36/60]  -- Loss = 0.41397651155357773  --  iteration [92/92]
# Epoch TEST [36/60]  -- Loss = 0.46111798675163934  --  iteration [23/23]
# Epoch TRAIN [37/60]  -- Loss = 0.40702313087556674  --  iteration [92/92]
# Epoch TEST [37/60]  -- Loss = 0.4442844079888385  --  iteration [23/23]]
# Epoch TRAIN [38/60]  -- Loss = 0.389744827442843  --  iteration [92/92]
# Epoch TEST [38/60]  -- Loss = 0.4414513117593268  --  iteration [23/23]
# Epoch TRAIN [39/60]  -- Loss = 0.3844239598383074  --  iteration [92/92]
# Epoch TEST [39/60]  -- Loss = 0.4560080675975136  --  iteration [23/23]]
# Epoch TRAIN [40/60]  -- Loss = 0.390365166346664  --  iteration [92/92]2]
# Epoch TEST [40/60]  -- Loss = 0.4445996018855468  --  iteration [23/23]]
# Epoch TRAIN [41/60]  -- Loss = 0.3703654184937477  --  iteration [92/92]]
# Epoch TEST [41/60]  -- Loss = 0.4388709722653679  --  iteration [23/23]]
# Epoch TRAIN [42/60]  -- Loss = 0.3634537926510624  --  iteration [92/92]]
# Epoch TEST [42/60]  -- Loss = 0.4504022967556249  --  iteration [23/23]
# Epoch TRAIN [43/60]  -- Loss = 0.3514888118952513  --  iteration [92/92]
# Epoch TEST [43/60]  -- Loss = 0.426135144803835  --  iteration [23/23]3]
# Epoch TRAIN [44/60]  -- Loss = 0.34856046201742213  --  iteration [92/92]
# Epoch TEST [44/60]  -- Loss = 0.4442717588466147  --  iteration [23/23]
# Epoch TRAIN [45/60]  -- Loss = 0.33600112560974515  --  iteration [92/92]
# Epoch TEST [45/60]  -- Loss = 0.43859404455060547  --  iteration [23/23]
# Epoch TRAIN [46/60]  -- Loss = 0.3322376001464284  --  iteration [92/92]
# Epoch TEST [46/60]  -- Loss = 0.4425716899011446  --  iteration [23/23]]
# Epoch TRAIN [47/60]  -- Loss = 0.3399382883115955  --  iteration [92/92]
# Epoch TEST [47/60]  -- Loss = 0.4292416961296745  --  iteration [23/23]
# Epoch TRAIN [48/60]  -- Loss = 0.33337264111184556  --  iteration [92/92]
# Epoch TEST [48/60]  -- Loss = 0.4305794349183207  --  iteration [23/23]]
# Epoch TRAIN [49/60]  -- Loss = 0.32788840810889786  --  iteration [92/92]
# Epoch TEST [49/60]  -- Loss = 0.4405643052381018  --  iteration [23/23]]
# Epoch TRAIN [50/60]  -- Loss = 0.3069543311291415  --  iteration [92/92]]
# Epoch TEST [50/60]  -- Loss = 0.44025331346885016  --  iteration [23/23]
# Epoch TRAIN [51/60]  -- Loss = 0.3104606349345135  --  iteration [92/92]
# Epoch TEST [51/60]  -- Loss = 0.4360114906145179  --  iteration [23/23]
# Epoch TRAIN [52/60]  -- Loss = 0.30584757119093253  --  iteration [92/92]
# Epoch TEST [52/60]  -- Loss = 0.44865899500639544  --  iteration [23/23]
# Epoch TRAIN [53/60]  -- Loss = 0.30790400521262834  --  iteration [92/92]
# Epoch TEST [53/60]  -- Loss = 0.4428682223610256  --  iteration [23/23]]
# Epoch TRAIN [54/60]  -- Loss = 0.29475574495027895  --  iteration [92/92]
# Epoch TEST [54/60]  -- Loss = 0.44633585797703784  --  iteration [23/23]
# Epoch TRAIN [55/60]  -- Loss = 0.2952580460063789  --  iteration [92/92]]
# Epoch TEST [55/60]  -- Loss = 0.4435355896535127  --  iteration [23/23]]
# Epoch TRAIN [56/60]  -- Loss = 0.2812461248072593  --  iteration [92/92]]
# Epoch TEST [56/60]  -- Loss = 0.4323461969261584  --  iteration [23/23]]
# Epoch TRAIN [57/60]  -- Loss = 0.2766066223544919  --  iteration [92/92]]
# Epoch TEST [57/60]  -- Loss = 0.4387461368156516  --  iteration [23/23]
# Epoch TRAIN [58/60]  -- Loss = 0.2603596303126086  --  iteration [92/92]]
# Epoch TEST [58/60]  -- Loss = 0.43360309367594513  --  iteration [23/23]
# Epoch TRAIN [59/60]  -- Loss = 0.2529673972369536  --  iteration [92/92]
# Epoch TEST [59/60]  -- Loss = 0.4361141181510428  --  iteration [23/23]
# Epoch TRAIN [60/60]  -- Loss = 0.2502599755383056  --  iteration [92/92]]
# Epoch TEST [60/60]  -- Loss = 0.4306502886440443  --  iteration [23/23]
# DONE
#
# Train and Test losses over epochs
# MODEL INFORMATION :
#
# CNN3_FC3(
#   (conv1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(8, 8), stride=(4, 4))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (lin1): Linear(in_features=256, out_features=128, bias=True)
#   (lin2): Linear(in_features=128, out_features=16, bias=True)
#   (lin3): Linear(in_features=16, out_features=1, bias=True)
#   (dout): Dropout(p=0.25, inplace=False)
# )
# Params to learn:
# 	 conv1.0.weight
# 	 conv1.0.bias
# 	 conv1.1.weight
# 	 conv1.1.bias
# 	 conv2.0.weight
# 	 conv2.0.bias
# 	 conv2.1.weight
# 	 conv2.1.bias
# 	 conv3.0.weight
# 	 conv3.0.bias
# 	 conv3.1.weight
# 	 conv3.1.bias
# 	 lin1.weight
# 	 lin1.bias
# 	 lin2.weight
# 	 lin2.bias
# 	 lin3.weight
# 	 lin3.bias
#
# TRAINNING :
# Epoch TRAIN [1/60]  -- Loss = 0.6699936056838316  --  iteration [68/68]
# Epoch TEST [1/60]  -- Loss = 0.6757914318757898  --  iteration [17/17]
# Epoch TRAIN [2/60]  -- Loss = 0.6481532980413998  --  iteration [68/68]
# Epoch TEST [2/60]  -- Loss = 0.6761749211479636  --  iteration [17/17]
# Epoch TRAIN [3/60]  -- Loss = 0.6315861239152796  --  iteration [68/68]
# Epoch TEST [3/60]  -- Loss = 0.6737136665512534  --  iteration [17/17]
# Epoch TRAIN [4/60]  -- Loss = 0.6340755715089685  --  iteration [68/68]
# Epoch TEST [4/60]  -- Loss = 0.6737538207979763  --  iteration [17/17]
# Epoch TRAIN [5/60]  -- Loss = 0.6342732630231801  --  iteration [68/68]
# Epoch TEST [5/60]  -- Loss = 0.6741949845762814  --  iteration [17/17]
# Epoch TRAIN [6/60]  -- Loss = 0.6285730674862862  --  iteration [68/68]
# Epoch TEST [6/60]  -- Loss = 0.6660368372412289  --  iteration [17/17]
# Epoch TRAIN [7/60]  -- Loss = 0.6248700136647505  --  iteration [68/68]
# Epoch TEST [7/60]  -- Loss = 0.6626179779277128  --  iteration [17/17]
# Epoch TRAIN [8/60]  -- Loss = 0.6225939879522604  --  iteration [68/68]
# Epoch TEST [8/60]  -- Loss = 0.6593591097523185  --  iteration [17/17]
# Epoch TRAIN [9/60]  -- Loss = 0.6176963124205085  --  iteration [68/68]
# Epoch TEST [9/60]  -- Loss = 0.6586703903534833  --  iteration [17/17]
# Epoch TRAIN [10/60]  -- Loss = 0.6150789181975758  --  iteration [68/68]
# Epoch TEST [10/60]  -- Loss = 0.6530728287556592  --  iteration [17/17]
# Epoch TRAIN [11/60]  -- Loss = 0.6142540482037208  --  iteration [68/68]
# Epoch TEST [11/60]  -- Loss = 0.6495290836867165  --  iteration [17/17]
# Epoch TRAIN [12/60]  -- Loss = 0.6024910049403415  --  iteration [68/68]
# Epoch TEST [12/60]  -- Loss = 0.6403208778185003  --  iteration [17/17]
# Epoch TRAIN [13/60]  -- Loss = 0.6048266984084073  --  iteration [68/68]
# Epoch TEST [13/60]  -- Loss = 0.6347722884486703  --  iteration [17/17]
# Epoch TRAIN [14/60]  -- Loss = 0.5951535425641957  --  iteration [68/68]
# Epoch TEST [14/60]  -- Loss = 0.6331329240518457  --  iteration [17/17]
# Epoch TRAIN [15/60]  -- Loss = 0.594309819095275  --  iteration [68/68]
# Epoch TEST [15/60]  -- Loss = 0.622865336782792  --  iteration [17/17]]
# Epoch TRAIN [16/60]  -- Loss = 0.5849944624830695  --  iteration [68/68]
# Epoch TEST [16/60]  -- Loss = 0.6188423896537107  --  iteration [17/17]
# Epoch TRAIN [17/60]  -- Loss = 0.5791470272576108  --  iteration [68/68]
# Epoch TEST [17/60]  -- Loss = 0.6111968159675598  --  iteration [17/17]
# Epoch TRAIN [18/60]  -- Loss = 0.5737172636915656  --  iteration [68/68]
# Epoch TEST [18/60]  -- Loss = 0.6021835120285258  --  iteration [17/17]
# Epoch TRAIN [19/60]  -- Loss = 0.5627366120324415  --  iteration [68/68]
# Epoch TEST [19/60]  -- Loss = 0.5967612652217641  --  iteration [17/17]
# Epoch TRAIN [20/60]  -- Loss = 0.5580717960701269  --  iteration [68/68]
# Epoch TEST [20/60]  -- Loss = 0.5832030352424172  --  iteration [17/17]
# Epoch TRAIN [21/60]  -- Loss = 0.5499813889755922  --  iteration [68/68]
# Epoch TEST [21/60]  -- Loss = 0.5743726421804989  --  iteration [17/17]
# Epoch TRAIN [22/60]  -- Loss = 0.5549449425409821  --  iteration [68/68]
# Epoch TEST [22/60]  -- Loss = 0.5707030138548683  --  iteration [17/17]
# Epoch TRAIN [23/60]  -- Loss = 0.5378763316308751  --  iteration [68/68]
# Epoch TEST [23/60]  -- Loss = 0.5631754170445835  --  iteration [17/17]
# Epoch TRAIN [24/60]  -- Loss = 0.527988872545607  --  iteration [68/68]]
# Epoch TEST [24/60]  -- Loss = 0.5523920427350437  --  iteration [17/17]
# Epoch TRAIN [25/60]  -- Loss = 0.5281810764880741  --  iteration [68/68]
# Epoch TEST [25/60]  -- Loss = 0.5450158469817218  --  iteration [17/17]
# Epoch TRAIN [26/60]  -- Loss = 0.5084732060923296  --  iteration [68/68]]
# Epoch TEST [26/60]  -- Loss = 0.5348149415324716  --  iteration [17/17]
# Epoch TRAIN [27/60]  -- Loss = 0.5104561908280149  --  iteration [68/68]]
# Epoch TEST [27/60]  -- Loss = 0.5283326787107131  --  iteration [17/17]
# Epoch TRAIN [28/60]  -- Loss = 0.5039941247771768  --  iteration [68/68]
# Epoch TEST [28/60]  -- Loss = 0.5188325941562653  --  iteration [17/17]
# Epoch TRAIN [29/60]  -- Loss = 0.48944506750387307  --  iteration [68/68]
# Epoch TEST [29/60]  -- Loss = 0.5130482140709373  --  iteration [17/17]
# Epoch TRAIN [30/60]  -- Loss = 0.49209296440376954  --  iteration [68/68]
# Epoch TEST [30/60]  -- Loss = 0.5055577369297252  --  iteration [17/17]]
# Epoch TRAIN [31/60]  -- Loss = 0.4730850024258389  --  iteration [68/68]]
# Epoch TEST [31/60]  -- Loss = 0.4950167203650755  --  iteration [17/17]]
# Epoch TRAIN [32/60]  -- Loss = 0.47048889319686327  --  iteration [68/68]
# Epoch TEST [32/60]  -- Loss = 0.492488855824751  --  iteration [17/17]]]
# Epoch TRAIN [33/60]  -- Loss = 0.46234727782361645  --  iteration [68/68]
# Epoch TEST [33/60]  -- Loss = 0.48729385698542876  --  iteration [17/17]
# Epoch TRAIN [34/60]  -- Loss = 0.45833444639163856  --  iteration [68/68]
# Epoch TEST [34/60]  -- Loss = 0.48801788863013773  --  iteration [17/17]
# Epoch TRAIN [35/60]  -- Loss = 0.452742317581878  --  iteration [68/68]8]
# Epoch TEST [35/60]  -- Loss = 0.4729348403566024  --  iteration [17/17]]
# Epoch TRAIN [36/60]  -- Loss = 0.4517963234992588  --  iteration [68/68]
# Epoch TEST [36/60]  -- Loss = 0.4741487169966978  --  iteration [17/17]]
# Epoch TRAIN [37/60]  -- Loss = 0.43933063241488796  --  iteration [68/68]
# Epoch TEST [37/60]  -- Loss = 0.47240764428587523  --  iteration [17/17]
# Epoch TRAIN [38/60]  -- Loss = 0.4483310310717891  --  iteration [68/68]]
# Epoch TEST [38/60]  -- Loss = 0.46854763171252084  --  iteration [17/17]
# Epoch TRAIN [39/60]  -- Loss = 0.43453750759363174  --  iteration [68/68]
# Epoch TEST [39/60]  -- Loss = 0.46555338186376233  --  iteration [17/17]
# Epoch TRAIN [40/60]  -- Loss = 0.43297530886004953  --  iteration [68/68]
# Epoch TEST [40/60]  -- Loss = 0.46232018751256604  --  iteration [17/17]
# Epoch TRAIN [41/60]  -- Loss = 0.43629751989946647  --  iteration [68/68]
# Epoch TEST [41/60]  -- Loss = 0.4675816560492796  --  iteration [17/17]]
# Epoch TRAIN [42/60]  -- Loss = 0.43077361846671386  --  iteration [68/68]
# Epoch TEST [42/60]  -- Loss = 0.4545259738669676  --  iteration [17/17]]
# Epoch TRAIN [43/60]  -- Loss = 0.40614250915891986  --  iteration [68/68]
# Epoch TEST [43/60]  -- Loss = 0.4605998361811918  --  iteration [17/17]]
# Epoch TRAIN [44/60]  -- Loss = 0.40269411552478285  --  iteration [68/68]
# Epoch TEST [44/60]  -- Loss = 0.4576197687317343  --  iteration [17/17]]
# Epoch TRAIN [45/60]  -- Loss = 0.412563254508902  --  iteration [68/68]
# Epoch TEST [45/60]  -- Loss = 0.45763258460689993  --  iteration [17/17]
# Epoch TRAIN [46/60]  -- Loss = 0.40733664088389454  --  iteration [68/68]
# Epoch TEST [46/60]  -- Loss = 0.45405202753403606  --  iteration [17/17]
# Epoch TRAIN [47/60]  -- Loss = 0.3983246578889735  --  iteration [68/68]]
# Epoch TEST [47/60]  -- Loss = 0.4523778338642681  --  iteration [17/17]]
# Epoch TRAIN [48/60]  -- Loss = 0.3982865832307759  --  iteration [68/68]]
# Epoch TEST [48/60]  -- Loss = 0.4614670399357291  --  iteration [17/17]]
# Epoch TRAIN [49/60]  -- Loss = 0.37790070627542105  --  iteration [68/68]
# Epoch TEST [49/60]  -- Loss = 0.4625064152128556  --  iteration [17/17]]
# Epoch TRAIN [50/60]  -- Loss = 0.38145731959272833  --  iteration [68/68]
# Epoch TEST [50/60]  -- Loss = 0.4582071164075066  --  iteration [17/17]]
# Epoch TRAIN [51/60]  -- Loss = 0.377558678826865  --  iteration [68/68]8]
# Epoch TEST [51/60]  -- Loss = 0.4632266409256879  --  iteration [17/17]]
# Epoch TRAIN [52/60]  -- Loss = 0.3641485725255573  --  iteration [68/68]]
# Epoch TEST [52/60]  -- Loss = 0.44681471586227417  --  iteration [17/17]
# Epoch TRAIN [53/60]  -- Loss = 0.38109685371027274  --  iteration [68/68]
# Epoch TEST [53/60]  -- Loss = 0.4590875243439394  --  iteration [17/17]]
# Epoch TRAIN [54/60]  -- Loss = 0.3586135092465317  --  iteration [68/68]]
# Epoch TEST [54/60]  -- Loss = 0.45293016731739044  --  iteration [17/17]
# Epoch TRAIN [55/60]  -- Loss = 0.36273475210456285  --  iteration [68/68]
# Epoch TEST [55/60]  -- Loss = 0.4480454614933799  --  iteration [17/17]]
# Epoch TRAIN [56/60]  -- Loss = 0.342863094938152  --  iteration [68/68]
# Epoch TEST [56/60]  -- Loss = 0.44622399000560536  --  iteration [17/17]
# Epoch TRAIN [57/60]  -- Loss = 0.34357136466047344  --  iteration [68/68]
# Epoch TEST [57/60]  -- Loss = 0.44980034933370705  --  iteration [17/17]
# Epoch TRAIN [58/60]  -- Loss = 0.331307740553337  --  iteration [68/68]
# Epoch TEST [58/60]  -- Loss = 0.4531672009650399  --  iteration [17/17]]
# Epoch TRAIN [59/60]  -- Loss = 0.3299501894370598  --  iteration [68/68]
# Epoch TEST [59/60]  -- Loss = 0.44786570878589854  --  iteration [17/17]
# Epoch TRAIN [60/60]  -- Loss = 0.3146507509929292  --  iteration [68/68]
# Epoch TEST [60/60]  -- Loss = 0.453308608602075  --  iteration [17/17]7]
# DONE
#
# Train and Test losses over epochs
